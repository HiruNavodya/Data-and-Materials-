# %% [markdown]
# # RF

# %% [markdown]
# ## Data Set 1

# %%
# INSTALLING **PACKAGES**


# !pip install statsmodels

! pip install optuna

# !pip install tabulate

# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations

# Visualization
import matplotlib.pyplot as plt  # Plotting library
import seaborn as sns  # Statistical data visualization
from matplotlib.colors import ListedColormap  # Colormap utilities

# Model Helpers
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler  # Preprocessing tools
from sklearn import model_selection, metrics, preprocessing  # Model selection, evaluation, and preprocessing
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV  # Model selection and evaluation
from sklearn.tree import DecisionTreeClassifier  # Decision tree classifier


# Statistical analysis
from statsmodels.stats.outliers_influence import variance_inflation_factor  # Variance inflation factor
from scipy.stats import pointbiserialr, chi2_contingency, spearmanr, entropy  # Statistical functions
from statsmodels.graphics.gofplots import qqplot  # Q-Q plot
from collections import Counter  # Container datatypes

# Tabulate
from tabulate import tabulate  # Pretty-print tabular data

# Set visualization style
#sns.set()  # Set Seaborn default style
#plt.style.use('ggplot')  # Set ggplot style for matplotlib



# LOADING THE DATA SET
#https://drive.google.com/file/d/1Z_KsoIumw-fvivVombIoWuRo0LOe2nCb/view?usp=sharing
#https://drive.google.com/file/d/1aD1PXfwEEZ_F2lQgxuPfj-TVbxQ6NajK/view?usp=sharing
import gdown
import pandas as pd



# Read Xlsx file
import matplotlib.pyplot as plt
import pandas as pd
import plotly.graph_objects as go
import pandas as pd
import numpy as np  # Ensure numpy is imported
from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Read Xlsx file
import matplotlib.pyplot as plt
import pandas as pd
import plotly.graph_objects as go
import pandas as pd
import numpy as np  # Ensure numpy is imported
from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

import pandas as pd
# Out:
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (2.3.1)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.16.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.4.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (0.9.0)

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import (mean_absolute_error, mean_squared_error,
                            mean_absolute_percentage_error, r2_score)
import pandas as pd

# Load data from the new Google Drive link
file_id = "1pI2WC2uOQARK3ayA6H4c1Eu2IRqURXbR"
download_url = f"https://drive.google.com/uc?id={file_id}"

# Read the data
df = pd.read_csv(download_url)

# Backup original DataFrame
df_backup = df.copy()

# Create datetime directly from differently named columns
df['Date'] = pd.to_datetime({
    'year': df['YEAR'],
    'month': df['MO'],
    'day': df['DY']
})

# Set Date as the index
df = df.set_index('Date')

# Drop unnecessary columns
df = df.drop(columns=["YEAR", "MO", "DY"])

# Display the DataFrame (optional in scripts)
print(df.head())
# Out:
#             WS10M_lag1     RH  MIN_TEMP   PREC    WD_sin    WD_cos  AVG_TEMP  \
# Date
# 2013-01-03        4.25  86.26     23.42  13.42  0.439939  0.898028      26.4
# 2013-01-04        4.75  86.31     22.93   8.79  0.424199  0.905569      25.1
# 2013-01-05        5.74  86.88     22.17   2.60  0.563526  0.826098      26.9
# 2013-01-06        5.79  88.09     23.47   1.65  0.460200  0.887815      27.3
# 2013-01-07        4.52  93.04     24.04  27.41  0.368125  0.929776      25.9
#
#             WS10M_lag2  SURF_PRESSSURE  MAX_TEMP  RH_lag1  WD_sin_lag1  \
# Date
# 2013-01-03        3.99           99.68     28.38    86.19     0.500000
# 2013-01-04        4.25           99.65     27.58    86.26     0.439939
# 2013-01-05        4.75           99.50     26.16    86.31     0.424199
# 2013-01-06        5.74           99.47     27.75    86.88     0.563526
# 2013-01-07        5.79           99.46     26.70    88.09     0.460200
#
#             WD_sin_lag2  SL_PRESSURE  PREC_lag1  WS10M
# Date
# 2013-01-03     0.600420       1011.0       1.09   4.75
# 2013-01-04     0.500000       1010.1      13.42   5.74
# 2013-01-05     0.439939       1007.5       8.79   5.79
# 2013-01-06     0.424199       1008.2       2.60   4.52
# 2013-01-07     0.563526       1009.2       1.65   4.66

# %%
df.columns
# Out:
# Index(['WS10M_lag1', 'RH', 'MIN_TEMP', 'PREC', 'WD_sin', 'WD_cos', 'AVG_TEMP',
#        'WS10M_lag2', 'SURF_PRESSSURE', 'MAX_TEMP', 'RH_lag1', 'WD_sin_lag1',
#        'WD_sin_lag2', 'SL_PRESSURE', 'PREC_lag1', 'WS10M'],
#       dtype='object')

# %%
df.columns
df
# Out:
#             WS10M_lag1     RH  MIN_TEMP   PREC    WD_sin    WD_cos  AVG_TEMP  \
# Date
# 2013-01-03        4.25  86.26     23.42  13.42  0.439939  0.898028      26.4
# 2013-01-04        4.75  86.31     22.93   8.79  0.424199  0.905569      25.1
# 2013-01-05        5.74  86.88     22.17   2.60  0.563526  0.826098      26.9
# 2013-01-06        5.79  88.09     23.47   1.65  0.460200  0.887815      27.3
# 2013-01-07        4.52  93.04     24.04  27.41  0.368125  0.929776      25.9
# ...                ...    ...       ...    ...       ...       ...       ...
# 2023-12-27        6.01  88.57     24.40   9.45  0.381070  0.924546      29.5
# 2023-12-28        6.43  90.59     25.51  13.93  0.634731  0.772734      28.5
# 2023-12-29        3.93  89.03     25.03   9.80  0.689620  0.724172      28.2
# 2023-12-30        2.59  87.47     24.71   9.98  0.564967  0.825113      28.4
# 2023-12-31        4.59  86.37     24.10  14.96  0.569280  0.822144      28.6
#
#             WS10M_lag2  SURF_PRESSSURE  MAX_TEMP  RH_lag1  WD_sin_lag1  \
# Date
# 2013-01-03        3.99           99.68     28.38    86.19     0.500000
# 2013-01-04        4.25           99.65     27.58    86.26     0.439939
# 2013-01-05        4.75           99.50     26.16    86.31     0.424199
# 2013-01-06        5.74           99.47     27.75    86.88     0.563526
# 2013-01-07        5.79           99.46     26.70    88.09     0.460200
# ...                ...             ...       ...      ...          ...
# 2023-12-27        4.29           99.66     30.35    86.27     0.483282
# 2023-12-28        6.01           99.58     29.37    88.57     0.381070
# 2023-12-29        6.43           99.69     29.30    90.59     0.634731
# 2023-12-30        3.93           99.67     29.54    89.03     0.689620
# 2023-12-31        2.59           99.69     30.03    87.47     0.564967
#
#             WD_sin_lag2  SL_PRESSURE  PREC_lag1  WS10M
# Date
# 2013-01-03     0.600420       1011.0       1.09   4.75
# 2013-01-04     0.500000       1010.1      13.42   5.74
# 2013-01-05     0.439939       1007.5       8.79   5.79
# 2013-01-06     0.424199       1008.2       2.60   4.52
# 2013-01-07     0.563526       1009.2       1.65   4.66
# ...                 ...          ...        ...    ...
# 2023-12-27     0.697165       1011.0       3.50   6.43
# 2023-12-28     0.483282       1010.9       9.45   3.93
# 2023-12-29     0.381070       1011.4      13.93   2.59
# 2023-12-30     0.634731       1010.9       9.80   4.59
# 2023-12-31     0.689620       1010.9       9.98   5.08
#
# [4015 rows x 16 columns]

# %% [markdown]
# ## Data Sets

# %%
# Function to calculate evaluation metrics
def evaluate(y_true, y_pred, label=""):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    r2 = r2_score(y_true, y_pred)
    print(f"{label} MSE: {mse:.4f}")
    print(f"{label} RMSE: {rmse:.4f}")
    print(f"{label} MAE: {mae:.4f}")
    print(f"{label} MAPE: {mape:.2f}%")
    print(f"{label} R²: {r2:.4f}")
    return mse, rmse, mae, mape, r2


# Define evaluation metric
def evaluate_metrics(y_true, y_pred, label=""):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    r2 = r2_score(y_true, y_pred)

    print(f"{label} MSE: {mse:.4f}")
    print(f"{label} RMSE: {rmse:.4f}")
    print(f"{label} MAE: {mae:.4f}")
    print(f"{label} MAPE: {mape:.2f}%")
    print(f"{label} R²: {r2:.4f}")
    return mse, rmse, mae, mape, r2

# %%
###########################################################################################
# Define the list of variables to select

X = df.drop(columns=['WS10M'])
# Select only those columns from X
 # Features (lagged variables)
y = df['WS10M']  # Target variable (wind speed)

# %%
# Define the split index
split_index = int(len(X) * 0.8)  # 80% for training, 20% for testing

# Training set
X_train = X[:split_index]
y_train = y[:split_index]

# Testing set
X_test = X[split_index:]
y_test = y[split_index:]

# %%
numerical_cols=df.columns
numerical_cols

print("X_train:")
print(X_train.head())
print("y_train:")
print(y_train.head())
print("X_test:")
print(X_test.head())
print("y_test:")
print(y_test.head())

# Print the shapes of the datasets
print("\nShapes:")
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train:
#             WS10M_lag1     RH  MIN_TEMP   PREC    WD_sin    WD_cos  AVG_TEMP  \
# Date
# 2013-01-03        4.25  86.26     23.42  13.42  0.439939  0.898028      26.4
# 2013-01-04        4.75  86.31     22.93   8.79  0.424199  0.905569      25.1
# 2013-01-05        5.74  86.88     22.17   2.60  0.563526  0.826098      26.9
# 2013-01-06        5.79  88.09     23.47   1.65  0.460200  0.887815      27.3
# 2013-01-07        4.52  93.04     24.04  27.41  0.368125  0.929776      25.9
#
#             WS10M_lag2  SURF_PRESSSURE  MAX_TEMP  RH_lag1  WD_sin_lag1  \
# Date
# 2013-01-03        3.99           99.68     28.38    86.19     0.500000
# 2013-01-04        4.25           99.65     27.58    86.26     0.439939
# 2013-01-05        4.75           99.50     26.16    86.31     0.424199
# 2013-01-06        5.74           99.47     27.75    86.88     0.563526
# 2013-01-07        5.79           99.46     26.70    88.09     0.460200
#
#             WD_sin_lag2  SL_PRESSURE  PREC_lag1
# Date
# 2013-01-03     0.600420       1011.0       1.09
# 2013-01-04     0.500000       1010.1      13.42
# 2013-01-05     0.439939       1007.5       8.79
# 2013-01-06     0.424199       1008.2       2.60
# 2013-01-07     0.563526       1009.2       1.65
# y_train:
# Date
# 2013-01-03    4.75
# 2013-01-04    5.74
# 2013-01-05    5.79
# 2013-01-06    4.52
# 2013-01-07    4.66
# Name: WS10M, dtype: float64
# X_test:
#             WS10M_lag1     RH  MIN_TEMP   PREC    WD_sin    WD_cos  AVG_TEMP  \
# Date
# 2021-10-20        3.92  84.94     25.38  14.81 -0.914254 -0.405142      27.9
# 2021-10-21        2.82  86.10     25.29  33.26 -0.930418 -0.366501      26.7
# 2021-10-22        2.79  85.41     24.59   9.53 -0.810042 -0.586372      28.1
# 2021-10-23        2.72  85.24     24.52   9.21 -0.570714 -0.821149      28.0
# 2021-10-24        4.30  85.16     24.15  10.47 -0.979223 -0.202787      26.6
#
#             WS10M_lag2  SURF_PRESSSURE  MAX_TEMP  RH_lag1  WD_sin_lag1  \
# Date
# 2021-10-20        6.13           99.71     28.73    83.84    -0.971549
# 2021-10-21        3.92           99.72     28.72    84.94    -0.914254
# 2021-10-22        2.82           99.79     28.80    86.10    -0.930418
# 2021-10-23        2.79           99.89     28.17    85.41    -0.810042
# 2021-10-24        2.72           99.86     27.91    85.24    -0.570714
#
#             WD_sin_lag2  SL_PRESSURE  PREC_lag1
# Date
# 2021-10-20    -0.995884       1011.5       4.97
# 2021-10-21    -0.971549       1011.6      14.81
# 2021-10-22    -0.914254       1012.0      33.26
# 2021-10-23    -0.930418       1012.9       9.53
# 2021-10-24    -0.810042       1012.6       9.21
# y_test:
# Date
# 2021-10-20    2.82
# 2021-10-21    2.79
# 2021-10-22    2.72
# 2021-10-23    4.30
# 2021-10-24    3.74
# Name: WS10M, dtype: float64
#
# Shapes:
# X_train shape: (3212, 15)
# y_train shape: (3212,)
# X_test shape: (803, 15)
# y_test shape: (803,)

# %%
# Evaluation Function
def evaluate_metrics(y_true, y_pred, label=""):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    r2 = r2_score(y_true, y_pred)

    print(f"{label} MSE: {mse:.4f}")
    print(f"{label} RMSE: {rmse:.4f}")
    print(f"{label} MAE: {mae:.4f}")
    print(f"{label} MAPE: {mape:.2f}%")
    print(f"{label} R²: {r2:.4f}")
    return mse, rmse, mae, mape, r2

# %%
# Evaluation Function
def evaluate(y_true, y_pred, label=""):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    r2 = r2_score(y_true, y_pred)

    print(f"{label} MSE: {mse:.4f}")
    print(f"{label} RMSE: {rmse:.4f}")
    print(f"{label} MAE: {mae:.4f}")
    print(f"{label} MAPE: {mape:.2f}%")
    print(f"{label} R²: {r2:.4f}")
    return mse, rmse, mae, mape, r2

# %% [markdown]
# # CNN

# %% [markdown]
# ## Original

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import tensorflow as tf

# Set seed for reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# Assuming you have these from before:
# X_train_sub, X_test_sub (with selected top features)
# y_train, y_test (target variables)
# ===== CRITICAL ADDITION: STANDARD SCALING =====
# ... [imports and seed setting] ...

# Standard Scaling
scaler = StandardScaler()
X_train_sub = scaler.fit_transform(X_train)  # Now a NumPy array
X_test_sub = scaler.transform(X_test)        # Now a NumPy array

# Reshape for Conv1D
X_train_cnn = np.expand_dims(X_train_sub, axis=1)  # Shape: [samples, 1, features]
X_test_cnn = np.expand_dims(X_test_sub, axis=1)     # Shape: [samples, 1, features]

# Convert targets to arrays
y_train_cnn = y_train.values
y_test_cnn = y_test.values



# Build CNN model
model = Sequential()
# Conv1D expects input shape = (timesteps, features)
model.add(Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=(X_train_cnn.shape[1], X_train_cnn.shape[2])))
model.add(Flatten())  # Flatten before Dense layers
model.add(Dense(50, activation='relu'))
model.add(Dense(1))  # Output layer for regression

model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# Train the model
history = model.fit(
    X_train_cnn, y_train_cnn,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)

# Predict
y_train_pred_cnn = model.predict(X_train_cnn).flatten()
y_test_pred_cnn = model.predict(X_test_cnn).flatten()

# Evaluation function
def evaluate(y_true, y_pred, label="Model"):
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"{label}: MSE = {mse:.4f}, MAE = {mae:.4f}, R² = {r2:.4f}")

print("\n--- CNN Evaluation ---")
evaluate(y_train_cnn, y_train_pred_cnn, label="Train (CNN)")
evaluate(y_test_cnn, y_test_pred_cnn, label="Test (CNN)")

# Comparison dataframe
comparison_df = pd.DataFrame({
    'Actual': y_test_cnn,
    'Predicted': y_test_pred_cnn
})

print(comparison_df.head(20))

# Plot results
plt.figure(figsize=(10, 6))
plt.plot(y_test_cnn, label='Actual', marker='o')
plt.plot(y_test_pred_cnn, label='Predicted', marker='x')
plt.title('Actual vs Predicted Values (Test Set) - CNN')
plt.xlabel('Sample Index')
plt.ylabel('Target Value')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.5470 - val_loss: 1.2116
# Epoch 2/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8950 - val_loss: 0.9042
# Epoch 3/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6583 - val_loss: 0.7588
# Epoch 4/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5633 - val_loss: 0.6837
# Epoch 5/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5177 - val_loss: 0.6390
# Epoch 6/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4901 - val_loss: 0.6101
# Epoch 7/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4702 - val_loss: 0.5912
# Epoch 8/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4541 - val_loss: 0.5768
# Epoch 9/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.4421 - val_loss: 0.5666
# Epoch 10/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4324 - val_loss: 0.5587
# Epoch 11/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.4241 - val_loss: 0.5510
# Epoch 12/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4175 - val_loss: 0.5452
# Epoch 13/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4109 - val_loss: 0.5422
# Epoch 14/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4052 - val_loss: 0.5385
# Epoch 15/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.3997 - val_loss: 0.5360
# Epoch 16/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3950 - val_loss: 0.5350
# Epoch 17/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3909 - val_loss: 0.5334
# Epoch 18/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.3872 - val_loss: 0.5317
# Epoch 19/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3828 - val_loss: 0.5295
# Epoch 20/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.3785 - val_loss: 0.5287
# Epoch 21/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.3745 - val_loss: 0.5280
# Epoch 22/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.3704 - val_loss: 0.5274
# Epoch 23/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3668 - val_loss: 0.5270
# Epoch 24/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3634 - val_loss: 0.5269
# Epoch 25/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3600 - val_loss: 0.5265
# Epoch 26/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3566 - val_loss: 0.5267
# Epoch 27/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3536 - val_loss: 0.5270
# Epoch 28/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3508 - val_loss: 0.5274
# Epoch 29/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3478 - val_loss: 0.5271
# Epoch 30/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3454 - val_loss: 0.5274
# Epoch 31/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3427 - val_loss: 0.5283
# Epoch 32/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3408 - val_loss: 0.5266
# Epoch 33/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3376 - val_loss: 0.5280
# Epoch 34/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3363 - val_loss: 0.5277
# Epoch 35/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3340 - val_loss: 0.5279
# Epoch 36/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3320 - val_loss: 0.5294
# Epoch 37/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3289 - val_loss: 0.5293
# Epoch 38/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3261 - val_loss: 0.5308
# Epoch 39/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3248 - val_loss: 0.5317
# Epoch 40/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3214 - val_loss: 0.5339
# Epoch 41/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3189 - val_loss: 0.5335
# Epoch 42/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3168 - val_loss: 0.5336
# Epoch 43/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3144 - val_loss: 0.5345
# Epoch 44/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3119 - val_loss: 0.5367
# Epoch 45/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3098 - val_loss: 0.5364
# Epoch 46/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3078 - val_loss: 0.5368
# Epoch 47/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3057 - val_loss: 0.5381
# Epoch 48/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3039 - val_loss: 0.5390
# Epoch 49/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3018 - val_loss: 0.5379
# Epoch 50/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3003 - val_loss: 0.5393
# Epoch 51/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2977 - val_loss: 0.5394
# Epoch 52/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2957 - val_loss: 0.5407
# Epoch 53/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2957 - val_loss: 0.5432
# Epoch 54/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2926 - val_loss: 0.5418
# Epoch 55/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2899 - val_loss: 0.5440
# Epoch 56/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2877 - val_loss: 0.5429
# Epoch 57/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2858 - val_loss: 0.5439
# Epoch 58/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2846 - val_loss: 0.5426
# Epoch 59/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2820 - val_loss: 0.5439
# Epoch 60/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2796 - val_loss: 0.5449
# Epoch 61/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2772 - val_loss: 0.5445
# Epoch 62/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2753 - val_loss: 0.5446
# Epoch 63/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2727 - val_loss: 0.5457
# Epoch 64/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2706 - val_loss: 0.5466
# Epoch 65/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2691 - val_loss: 0.5491
# Epoch 66/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2668 - val_loss: 0.5496
# Epoch 67/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2645 - val_loss: 0.5517
# Epoch 68/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2629 - val_loss: 0.5546
# Epoch 69/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2610 - val_loss: 0.5505
# Epoch 70/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2580 - val_loss: 0.5543
# Epoch 71/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2570 - val_loss: 0.5553
# Epoch 72/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2548 - val_loss: 0.5552
# Epoch 73/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2536 - val_loss: 0.5545
# Epoch 74/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2522 - val_loss: 0.5560
# Epoch 75/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2497 - val_loss: 0.5553
# Epoch 76/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2487 - val_loss: 0.5565
# Epoch 77/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2466 - val_loss: 0.5569
# Epoch 78/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2459 - val_loss: 0.5584
# Epoch 79/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2445 - val_loss: 0.5588
# Epoch 80/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2424 - val_loss: 0.5588
# Epoch 81/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2413 - val_loss: 0.5590
# Epoch 82/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2400 - val_loss: 0.5595
# Epoch 83/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2386 - val_loss: 0.5616
# Epoch 84/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2377 - val_loss: 0.5625
# Epoch 85/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2355 - val_loss: 0.5639
# Epoch 86/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2344 - val_loss: 0.5633
# Epoch 87/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2329 - val_loss: 0.5672
# Epoch 88/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2313 - val_loss: 0.5659
# Epoch 89/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2308 - val_loss: 0.5680
# Epoch 90/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2290 - val_loss: 0.5690
# Epoch 91/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2278 - val_loss: 0.5702
# Epoch 92/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2270 - val_loss: 0.5696
# Epoch 93/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2260 - val_loss: 0.5726
# Epoch 94/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2245 - val_loss: 0.5730
# Epoch 95/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2238 - val_loss: 0.5751
# Epoch 96/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2225 - val_loss: 0.5718
# Epoch 97/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2216 - val_loss: 0.5763
# Epoch 98/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2203 - val_loss: 0.5755
# Epoch 99/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2194 - val_loss: 0.5777
# Epoch 100/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2183 - val_loss: 0.5785
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# --- CNN Evaluation ---
# Train (CNN): MSE = 0.2831, MAE = 0.4026, R² = 0.8876
# Test (CNN): MSE = 0.6719, MAE = 0.6296, R² = 0.7214
#     Actual  Predicted
# 0     2.82   3.552928
# 1     2.79   3.337261
# 2     2.72   2.349525
# 3     4.30   3.237550
# 4     3.74   3.725887
# 5     2.69   3.277943
# 6     2.37   2.706418
# 7     2.30   2.118274
# 8     3.50   4.120634
# 9     4.15   3.264952
# 10    1.97   4.267887
# 11    5.60   2.925131
# 12    6.11   6.403975
# 13    2.57   3.709113
# 14    3.27   3.350425
# 15    3.36   3.464601
# 16    3.55   3.338966
# 17    4.03   3.234900
# 18    5.18   3.646259
# 19    5.81   4.974612

# %%
# !pip install scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from scikeras) (3.8.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from scikeras) (1.6.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (3.14.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.16.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (25.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras>=3.2.0->scikeras) (4.14.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0

# %%
import sklearn, scikeras, tensorflow
print("scikit-learn:", sklearn.__version__)
print("scikeras:", scikeras.__version__)
print("tensorflow:", tensorflow.__version__)
# Out:
# scikit-learn: 1.6.1
# scikeras: 0.13.0
# tensorflow: 2.18.0

# %%
# !pip install --force-reinstall --no-cache-dir numpy scikit-learn
# Out:
# Collecting numpy
#   Downloading numpy-2.3.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 27.2 MB/s eta 0:00:00
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 8.6 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading numpy-2.3.1-cp311-cp311-manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 54.7 MB/s eta 0:00:00
# Downloading scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 73.3 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 224.1 MB/s eta 0:00:00
# Downloading scipy-1.16.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 93.9 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, numpy, joblib, scipy, scikit-learn
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.6.0
#     Uninstalling threadpoolctl-3.6.0:
#       Successfully uninstalled threadpoolctl-3.6.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.5.1
#     Uninstalling joblib-1.5.1:
#       Successfully uninstalled joblib-1.5.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.0
#     Uninstalling scipy-1.16.0:
#       Successfully uninstalled scipy-1.16.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.1 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.1 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.3.1 which is incompatible.
# cupy-cuda12x 13.3.0 requires numpy<2.3,>=1.22, but you have numpy 2.3.1 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.1 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.1 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.1 which is incompatible.
# Successfully installed joblib-1.5.1 numpy-2.3.1 scikit-learn-1.7.1 scipy-1.16.0 threadpoolctl-3.6.0

# %% [markdown]
# ## Grid Search

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
#from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from scikeras.wrappers import KerasRegressor

from tensorflow.keras.optimizers import Adam
# Fix random seed for reproducibility
RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# Standard Scaling
scaler = StandardScaler()
X_train_sub = scaler.fit_transform(X_train)  # Now a NumPy array
X_test_sub = scaler.transform(X_test)        # Now a NumPy array

# Reshape for Conv1D
X_train_cnn = np.expand_dims(X_train_sub, axis=1)  # Shape: [samples, 1, features]
X_test_cnn = np.expand_dims(X_test_sub, axis=1)     # Shape: [samples, 1, features]

# Convert targets to arrays
y_train_cnn = y_train.values
y_test_cnn = y_test.values


# Evaluation function (same as yours)
def evaluate_metrics(y_true, y_pred, label=""):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    r2 = r2_score(y_true, y_pred)

    print(f"{label} MSE: {mse:.4f}")
    print(f"{label} RMSE: {rmse:.4f}")
    print(f"{label} MAE: {mae:.4f}")
    print(f"{label} MAPE: {mape:.2f}%")
    print(f"{label} R²: {r2:.4f}")
    return mse, rmse, mae, mape, r2

# Build CNN model builder function for KerasRegressor
def build_cnn_model(filters=64, kernel_size=1, dropout_rate=0.2, learning_rate=0.001):
    model = Sequential()
    model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='relu', input_shape=(1, X_train.shape[1])))
    model.add(Flatten())
    model.add(Dropout(dropout_rate))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(loss='mse', optimizer=optimizer)
    return model

# Wrap Keras model for sklearn compatibility
cnn_regressor = KerasRegressor(model=build_cnn_model, verbose=0)

# Parameter grid with correct scikeras prefixes
param_grid = {
    'model__filters': [32, 64, 128],
    'model__dropout_rate': [0.1, 0.2, 0.3],
    'model__learning_rate': [1e-2, 1e-3, 1e-4],
    'batch_size': [16, 32],
    'epochs': [50, 100]
}

# TimeSeriesSplit for cross-validation
tscv = TimeSeriesSplit(n_splits=5)

# Setup GridSearchCV
grid_search = GridSearchCV(
    estimator=cnn_regressor,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',
    cv=tscv,
    verbose=2,
    n_jobs=1  # Parallelism with TF often causes issues
)

# Fit grid search (this will take time)
grid_search.fit(X_train_cnn, y_train)

print("\nBest Parameters found:")
print(grid_search.best_params_)

# Best model from grid search
best_cnn = grid_search.best_estimator_

# Predictions
y_train_pred = best_cnn.predict(X_train_cnn)
y_test_pred = best_cnn.predict(X_test_cnn)

print("\n--- Optimized CNN Evaluation ---")
evaluate_metrics(y_train, y_train_pred, label="Train (CNN Optimized)")
evaluate_metrics(y_test, y_test_pred, label="Test (CNN Optimized)")

# Plot results
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='Actual', color='black', linewidth=2)
plt.plot(y_test_pred, label='Predicted (CNN Optimized)', color='blue', linestyle='--', linewidth=2)
plt.title('Actual vs Predicted Values on Test Set (Optimized CNN)')
plt.xlabel('Observation Index')
plt.ylabel('Target Value')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  21.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  11.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  16.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  18.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  31.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=   8.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  15.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  16.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  18.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  28.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=   9.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  12.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  17.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  18.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  25.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=   8.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  14.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  16.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  18.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  28.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=   7.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  13.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  16.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  18.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  27.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=   7.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  14.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  17.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  17.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  28.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=   8.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  13.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  17.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  17.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  27.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=   8.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  13.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  17.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  18.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  28.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=   9.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  15.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  19.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  17.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  27.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=   7.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  13.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  16.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  18.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  28.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=   8.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  14.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  15.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  18.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  27.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=   8.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  14.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  16.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  18.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  26.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=   8.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  13.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  16.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  18.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  28.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=   8.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  14.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  15.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  18.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  29.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=   9.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  24.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  16.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  19.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  31.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=   9.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  13.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  16.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  19.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  30.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=   9.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  14.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  16.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  18.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  27.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=   8.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  13.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  16.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  21.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  28.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  10.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  14.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  17.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  18.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  29.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=   8.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  14.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  17.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  18.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  27.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=   8.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  12.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  17.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  20.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  28.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=   9.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  14.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  17.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  19.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  24.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=   9.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  14.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  17.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  19.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  30.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=   8.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  13.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  17.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  19.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  29.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=   8.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  12.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  17.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  17.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  28.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=   8.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  14.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  17.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  17.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  29.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=   8.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  14.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  17.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  17.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  30.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  14.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  24.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  31.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  34.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  53.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  15.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  24.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  35.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  39.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  53.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  16.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  26.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  31.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  36.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  55.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  15.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  27.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  33.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  33.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  56.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  15.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  26.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  33.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  40.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  55.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  16.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  28.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  34.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  50.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  59.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  15.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  25.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  34.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  34.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  56.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  16.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  25.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  31.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  40.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  58.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  19.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  28.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  34.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  53.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time= 1.1min
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  20.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  27.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  35.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  47.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  59.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  16.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  26.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  33.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  44.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  57.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  15.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  27.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  31.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  41.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  53.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  15.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  25.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  33.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  35.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  55.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  15.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  23.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  31.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  34.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  54.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  15.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  29.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  31.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  35.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  55.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  15.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  26.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  32.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  51.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  59.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  15.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  26.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  33.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  47.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  56.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  16.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  27.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  31.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  37.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  58.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  15.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  27.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  33.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  44.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  59.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  16.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  25.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  32.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  45.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  57.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  15.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  24.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  32.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  35.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  55.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  15.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  26.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  32.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  38.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  59.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  16.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  26.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  32.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  41.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  56.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  15.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  24.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  32.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  36.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  54.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  14.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  25.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  34.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  37.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  53.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  16.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  25.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  31.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  38.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  55.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  15.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  24.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  33.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  35.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  56.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=   7.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=   7.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=   9.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  13.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  14.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=   7.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=   8.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=   8.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  13.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  14.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=   7.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=   8.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=   9.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  13.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  15.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=   7.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=   7.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  10.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  12.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  16.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=   7.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=   8.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=   9.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  15.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  15.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=   6.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=   8.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=   9.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  13.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  14.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=   7.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=   7.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=   9.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  14.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  15.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=   6.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=   9.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  10.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  16.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  18.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=   7.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=   9.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  11.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  15.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  16.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=   7.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=   9.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  10.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  13.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  15.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=   7.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=   8.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=   9.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  12.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  15.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=   7.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=   8.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  10.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  13.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  15.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=   6.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=   8.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  10.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  13.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  15.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=   7.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=   8.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=   9.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  13.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  16.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=   6.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=   9.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  10.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  14.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  15.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=   7.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=   9.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=   8.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  14.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  16.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=   6.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=   8.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  10.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  13.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  14.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=   7.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=   7.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=   9.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  13.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  16.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=   7.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=   8.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=   9.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  13.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  14.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=   7.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=   8.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  13.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  14.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  17.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=   7.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=   8.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  10.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  13.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  14.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=   7.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=   8.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=   9.4s
# ...
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  30.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  13.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  14.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  16.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  25.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  28.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  13.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  14.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  17.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  25.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  28.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  12.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  14.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  17.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  25.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  28.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  12.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  21.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  21.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  27.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  31.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  13.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  15.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  19.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  27.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  29.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  13.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  15.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  19.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  28.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  29.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  12.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  15.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  19.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  27.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  28.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  12.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  16.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  18.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  23.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  30.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  13.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  14.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  18.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  24.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  26.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  12.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  15.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  16.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  25.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  28.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  12.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  16.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  16.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  24.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  28.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  13.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  15.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  16.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  25.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  29.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  12.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  15.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  17.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  26.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  28.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  12.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  15.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  17.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  26.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  31.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  12.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  15.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  18.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  26.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  31.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  13.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  14.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  18.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  26.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  28.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  13.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  14.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  18.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  26.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  27.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  12.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  15.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  16.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  26.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  28.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  12.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  15.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  16.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  24.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  28.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  13.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  16.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  27.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  26.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  28.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  13.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  15.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  17.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  26.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  29.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  12.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  15.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  20.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  27.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  29.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  13.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  16.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  18.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  27.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  29.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  12.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  15.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  18.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  26.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  29.5s
#
# Best Parameters found:
# {'batch_size': 32, 'epochs': 50, 'model__dropout_rate': 0.2, 'model__filters': 128, 'model__learning_rate': 0.001}
#
# --- Optimized CNN Evaluation ---
# Train (CNN Optimized) MSE: 0.3391
# Train (CNN Optimized) RMSE: 0.5824
# Train (CNN Optimized) MAE: 0.4570
# Train (CNN Optimized) MAPE: 12.32%
# Train (CNN Optimized) R²: 0.8654
# Test (CNN Optimized) MSE: 0.5359
# Test (CNN Optimized) RMSE: 0.7321
# Test (CNN Optimized) MAE: 0.5638
# Test (CNN Optimized) MAPE: 15.02%
# Test (CNN Optimized) R²: 0.7778

# %% [markdown]
# ## Random Search

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense, Dropout
from scikeras.wrappers import KerasRegressor
from tensorflow.keras.optimizers import Adam
from scipy.stats import randint, uniform
import tensorflow as tf
import random

# Fix random seed for reproducibility
RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# Standard Scaling
scaler = StandardScaler()
X_train_sub = scaler.fit_transform(X_train)  # Now a NumPy array
X_test_sub = scaler.transform(X_test)        # Now a NumPy array

# Reshape for Conv1D
X_train_cnn = np.expand_dims(X_train_sub, axis=1)  # Shape: [samples, 1, features]
X_test_cnn = np.expand_dims(X_test_sub, axis=1)     # Shape: [samples, 1, features]

# Convert targets to arrays
y_train_cnn = y_train.values
y_test_cnn = y_test.values


# Define CNN model builder function for KerasRegressor
def create_cnn_model(filters=64, dropout_rate=0.2, learning_rate=0.001):
    model = Sequential()
    model.add(Conv1D(filters=filters, kernel_size=1, activation='relu', input_shape=(1, X_train.shape[1])))
    model.add(Flatten())
    model.add(Dropout(dropout_rate))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))  # Regression output
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(loss='mse', optimizer=optimizer)
    return model

# Wrap model for sklearn compatibility
from scikeras.wrappers import KerasRegressor

cnn_regressor = KerasRegressor(
    model=create_cnn_model,
    verbose=0,
    filters=64,
    dropout_rate=0.2,
    learning_rate=0.001
)

# Define hyperparameter distribution for RandomizedSearchCV
param_dist = {
    'filters': randint(20, 151),
    'dropout_rate': uniform(0.1, 0.3),
    'learning_rate': uniform(1e-4, 9e-3),
    'batch_size': randint(16, 65),
    'epochs': randint(50, 151)
}

# Setup RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=cnn_regressor,
    param_distributions=param_dist,
    n_iter=10,
    cv=3,
    random_state=RANDOM_SEED,
    verbose=2,
    n_jobs=1
)

# Fit RandomizedSearchCV
random_search.fit(X_train_cnn, y_train)

# Best parameters
print("Best Hyperparameters:", random_search.best_params_)

# Predict on train and test sets using best estimator
y_train_pred_cnn = random_search.predict(X_train_cnn)
y_test_pred_cnn = random_search.predict(X_test_cnn)

# Evaluation function
def evaluate(y_true, y_pred, label="Model"):
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"{label}: MSE = {mse:.4f}, MAE = {mae:.4f}, R² = {r2:.4f}")

print("\n--- CNN Evaluation ---")
evaluate(y_train, y_train_pred_cnn, label="Train (CNN)")
evaluate(y_test, y_test_pred_cnn, label="Test (CNN)")

# Create a DataFrame to compare actual and predicted values on test set
comparison_df = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_test_pred_cnn
})

print(comparison_df.head(20))

# Plot actual vs predicted for test set
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='Actual', marker='o')
plt.plot(y_test_pred_cnn, label='Predicted', marker='x')
plt.title('Actual vs Predicted Values (Test Set) - CNN')
plt.xlabel('Sample Index')
plt.ylabel('Target Value')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] END batch_size=54, dropout_rate=0.33896289605806984, epochs=64, filters=126, learning_rate=0.007117219002454924; total time=  13.7s
# [CV] END batch_size=54, dropout_rate=0.33896289605806984, epochs=64, filters=126, learning_rate=0.007117219002454924; total time=  13.3s
# [CV] END batch_size=54, dropout_rate=0.33896289605806984, epochs=64, filters=126, learning_rate=0.007117219002454924; total time=  13.8s
# [CV] END batch_size=36, dropout_rate=0.14680559213273095, epochs=132, filters=94, learning_rate=0.004233240027692805; total time=  33.6s
# [CV] END batch_size=36, dropout_rate=0.14680559213273095, epochs=132, filters=94, learning_rate=0.004233240027692805; total time=  34.0s
# [CV] END batch_size=36, dropout_rate=0.14680559213273095, epochs=132, filters=94, learning_rate=0.004233240027692805; total time=  33.8s
# [CV] END batch_size=51, dropout_rate=0.14286004537658223, epochs=52, filters=72, learning_rate=0.008829188669457947; total time=  10.6s
# [CV] END batch_size=51, dropout_rate=0.14286004537658223, epochs=52, filters=72, learning_rate=0.008829188669457947; total time=  10.7s
# [CV] END batch_size=51, dropout_rate=0.14286004537658223, epochs=52, filters=72, learning_rate=0.008829188669457947; total time=   9.9s
# [CV] END batch_size=59, dropout_rate=0.381565812704725, epochs=51, filters=40, learning_rate=0.005657333586649448; total time=   9.7s
# [CV] END batch_size=59, dropout_rate=0.381565812704725, epochs=51, filters=40, learning_rate=0.005657333586649448; total time=   8.5s
# [CV] END batch_size=59, dropout_rate=0.381565812704725, epochs=51, filters=40, learning_rate=0.005657333586649448; total time=   9.5s
# [CV] END batch_size=37, dropout_rate=0.10211989156591522, epochs=138, filters=68, learning_rate=0.004822971942325502; total time=  36.1s
# [CV] END batch_size=37, dropout_rate=0.10211989156591522, epochs=138, filters=68, learning_rate=0.004822971942325502; total time=  36.4s
# [CV] END batch_size=37, dropout_rate=0.10211989156591522, epochs=138, filters=68, learning_rate=0.004822971942325502; total time=  36.1s
# [CV] END batch_size=57, dropout_rate=0.11399969896408463, epochs=109, filters=34, learning_rate=0.0042046298579533235; total time=  18.1s
# [CV] END batch_size=57, dropout_rate=0.11399969896408463, epochs=109, filters=34, learning_rate=0.0042046298579533235; total time=  19.1s
# [CV] END batch_size=57, dropout_rate=0.11399969896408463, epochs=109, filters=34, learning_rate=0.0042046298579533235; total time=  18.2s
# [CV] END batch_size=62, dropout_rate=0.28551580279992617, epochs=104, filters=83, learning_rate=0.00430086603923182; total time=  18.9s
# [CV] END batch_size=62, dropout_rate=0.28551580279992617, epochs=104, filters=83, learning_rate=0.00430086603923182; total time=  17.5s
# [CV] END batch_size=62, dropout_rate=0.28551580279992617, epochs=104, filters=83, learning_rate=0.00430086603923182; total time=  18.1s
# [CV] END batch_size=52, dropout_rate=0.28226345557043153, epochs=70, filters=92, learning_rate=0.0006854643368675156; total time=  14.2s
# [CV] END batch_size=52, dropout_rate=0.28226345557043153, epochs=70, filters=92, learning_rate=0.0006854643368675156; total time=  13.2s
# [CV] END batch_size=52, dropout_rate=0.28226345557043153, epochs=70, filters=92, learning_rate=0.0006854643368675156; total time=  13.3s
# [CV] END batch_size=19, dropout_rate=0.3826605267054558, epochs=63, filters=28, learning_rate=0.00024369626998192772; total time=  22.7s
# [CV] END batch_size=19, dropout_rate=0.3826605267054558, epochs=63, filters=28, learning_rate=0.00024369626998192772; total time=  23.1s
# [CV] END batch_size=19, dropout_rate=0.3826605267054558, epochs=63, filters=28, learning_rate=0.00024369626998192772; total time=  23.1s
# [CV] END batch_size=17, dropout_rate=0.30526990795364706, epochs=109, filters=27, learning_rate=0.0004094966900369655; total time=  40.0s
# [CV] END batch_size=17, dropout_rate=0.30526990795364706, epochs=109, filters=27, learning_rate=0.0004094966900369655; total time=  37.4s
# [CV] END batch_size=17, dropout_rate=0.30526990795364706, epochs=109, filters=27, learning_rate=0.0004094966900369655; total time=  37.3s
# Best Hyperparameters: {'batch_size': 52, 'dropout_rate': np.float64(0.28226345557043153), 'epochs': 70, 'filters': 92, 'learning_rate': np.float64(0.0006854643368675156)}
#
# --- CNN Evaluation ---
# Train (CNN): MSE = 0.4151, MAE = 0.4986, R² = 0.8352
# Test (CNN): MSE = 0.5867, MAE = 0.5894, R² = 0.7567
#             Actual  Predicted
# Date
# 2021-10-20    2.82   3.450398
# 2021-10-21    2.79   2.413643
# 2021-10-22    2.72   2.265199
# 2021-10-23    4.30   2.590168
# 2021-10-24    3.74   3.323076
# 2021-10-25    2.69   3.407152
# 2021-10-26    2.37   2.734368
# 2021-10-27    2.30   2.577338
# 2021-10-28    3.50   2.799972
# 2021-10-29    4.15   3.566941
# 2021-10-30    1.97   3.368123
# 2021-10-31    5.60   2.743891
# 2021-11-01    6.11   5.126621
# 2021-11-02    2.57   3.725159
# 2021-11-03    3.27   2.557050
# 2021-11-04    3.36   3.347748
# 2021-11-05    3.55   3.381139
# 2021-11-06    4.03   3.741751
# 2021-11-07    5.18   4.146659
# 2021-11-08    5.81   4.821953

# %% [markdown]
# ## optuna

# %%
import optuna
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# ===== CRITICAL ADDITION: STANDARD SCALING =====
# Standard Scaling
scaler = StandardScaler()
X_train_sub = scaler.fit_transform(X_train)  # Now a NumPy array
X_test_sub = scaler.transform(X_test)        # Now a NumPy array

# Reshape for Conv1D
X_train_cnn = np.expand_dims(X_train_sub, axis=1)  # Shape: [samples, 1, features]
X_test_cnn = np.expand_dims(X_test_sub, axis=1)     # Shape: [samples, 1, features]

# Convert targets to arrays
y_train_cnn = y_train.values
y_test_cnn = y_test.values



# Fix random seed
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)



# Evaluation function (same as you used)
def evaluate_metrics(y_true, y_pred, label=""):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    r2 = r2_score(y_true, y_pred)

    print(f"{label} MSE: {mse:.4f}")
    print(f"{label} RMSE: {rmse:.4f}")
    print(f"{label} MAE: {mae:.4f}")
    print(f"{label} MAPE: {mape:.2f}%")
    print(f"{label} R²: {r2:.4f}")
    return mse, rmse, mae, mape, r2

# Build CNN model function for Optuna
def create_cnn_model(trial):
    filters = trial.suggest_int('filters', 20, 150)
    dropout_rate = trial.suggest_float('dropout_rate', 0.1, 0.5)
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-4, 1e-2)

    model = Sequential()
    model.add(Conv1D(filters=filters, kernel_size=1, activation='relu', input_shape=(1, X_train.shape[1])))
    model.add(Flatten())
    model.add(Dropout(dropout_rate))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))  # Regression output
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(loss='mse', optimizer=optimizer)
    return model

# Optuna objective for CNN
def cnn_objective(trial):
    batch_size = trial.suggest_categorical('batch_size', [16, 32, 64])
    epochs = trial.suggest_int('epochs', 50, 150)

    model = create_cnn_model(trial)

    tscv = TimeSeriesSplit(n_splits=5)
    rmse_scores = []

    for train_idx, val_idx in tscv.split(X_train_cnn):
        X_t, X_v = X_train_cnn[train_idx], X_train_cnn[val_idx]
        y_t, y_v = y_train.iloc[train_idx], y_train.iloc[val_idx]

        history = model.fit(
            X_t, y_t,
            validation_data=(X_v, y_v),
            epochs=epochs,
            batch_size=batch_size,
            verbose=0,
            shuffle=False
        )
        preds = model.predict(X_v).flatten()
        rmse = mean_squared_error(y_v, preds)
        rmse_scores.append(rmse)

    return np.mean(rmse_scores)

# Create and run Optuna study
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED))
study.optimize(cnn_objective, n_trials=30, timeout=600)

print("\nBest Trial:")
print(study.best_trial)
print("\nBest Parameters:")
print(study.best_params)

# Refit final model on full train data with best params
best_params = study.best_params

final_model = Sequential()
final_model.add(Conv1D(filters=best_params['filters'], kernel_size=1, activation='relu', input_shape=(1, X_train.shape[1])))
final_model.add(Flatten())
final_model.add(Dropout(best_params['dropout_rate']))
final_model.add(Dense(50, activation='relu'))
final_model.add(Dense(1))
optimizer = Adam(learning_rate=best_params['learning_rate'])
final_model.compile(loss='mse', optimizer=optimizer)

final_model.fit(
    X_train_cnn, y_train,
    epochs=best_params['epochs'],
    batch_size=best_params['batch_size'],
    verbose=1,
    shuffle=False
)

# Predict
y_train_pred = final_model.predict(X_train_cnn).flatten()
y_test_pred = final_model.predict(X_test_cnn).flatten()

print("\n--- Optimized CNN Evaluation ---")
evaluate_metrics(y_train, y_train_pred, label="Train (CNN Optimized)")
evaluate_metrics(y_test, y_test_pred, label="Test (CNN Optimized)")

# Plot results
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='Actual', color='black', linewidth=2)
plt.plot(y_test_pred, label='Predicted (CNN Optimized)', color='blue', linestyle='--', linewidth=2)
plt.title('Actual vs Predicted Values on Test Set (Optimized CNN)')
plt.xlabel('Observation Index')
plt.ylabel('Target Value')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# [I 2025-07-23 09:58:34,275] A new study created in memory with name: no-name-716b0afd-32d9-4ed9-8456-630cda41ef80
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [I 2025-07-23 10:01:30,646] Trial 0 finished with value: 0.6069714606129052 and parameters: {'batch_size': 32, 'epochs': 110, 'filters': 40, 'dropout_rate': 0.16239780813448107, 'learning_rate': 0.00013066739238053285}. Best is trial 0 with value: 0.6069714606129052.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [I 2025-07-23 10:03:43,221] Trial 1 finished with value: 0.5479251504385928 and parameters: {'batch_size': 16, 'epochs': 52, 'filters': 147, 'dropout_rate': 0.4329770563201687, 'learning_rate': 0.00026587543983272726}. Best is trial 1 with value: 0.5479251504385928.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [I 2025-07-23 10:05:49,343] Trial 2 finished with value: 0.6018458908108614 and parameters: {'batch_size': 64, 'epochs': 103, 'filters': 76, 'dropout_rate': 0.21649165607921678, 'learning_rate': 0.0016738085788752138}. Best is trial 1 with value: 0.5479251504385928.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [I 2025-07-23 10:07:44,831] Trial 3 finished with value: 0.5839677816255346 and parameters: {'batch_size': 64, 'epochs': 96, 'filters': 122, 'dropout_rate': 0.1798695128633439, 'learning_rate': 0.0010677482709481358}. Best is trial 1 with value: 0.5479251504385928.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [I 2025-07-23 10:09:00,756] Trial 4 finished with value: 1.5359535396141608 and parameters: {'batch_size': 64, 'epochs': 67, 'filters': 28, 'dropout_rate': 0.4795542149013333, 'learning_rate': 0.00853618986286683}. Best is trial 1 with value: 0.5479251504385928.
# Best Trial:
# FrozenTrial(number=1, state=1, values=[0.5479251504385928], datetime_start=datetime.datetime(2025, 7, 23, 10, 1, 30, 647734), datetime_complete=datetime.datetime(2025, 7, 23, 10, 3, 43, 221289), params={'batch_size': 16, 'epochs': 52, 'filters': 147, 'dropout_rate': 0.4329770563201687, 'learning_rate': 0.00026587543983272726}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'batch_size': CategoricalDistribution(choices=(16, 32, 64)), 'epochs': IntDistribution(high=150, log=False, low=50, step=1), 'filters': IntDistribution(high=150, log=False, low=20, step=1), 'dropout_rate': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'learning_rate': FloatDistribution(high=0.01, log=True, low=0.0001, step=None)}, trial_id=1, value=None)
#
# Best Parameters:
# {'batch_size': 16, 'epochs': 52, 'filters': 147, 'dropout_rate': 0.4329770563201687, 'learning_rate': 0.00026587543983272726}
# Epoch 1/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 16.5821
# Epoch 2/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.7745
# Epoch 3/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.2809
# Epoch 4/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.1309
# Epoch 5/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.0654
# Epoch 6/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.9560
# Epoch 7/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8978
# Epoch 8/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8778
# Epoch 9/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8695
# Epoch 10/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.7956
# Epoch 11/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7686
# Epoch 12/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7540
# Epoch 13/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7070
# Epoch 14/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.7326
# Epoch 15/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6992
# Epoch 16/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6670
# Epoch 17/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6267
# Epoch 18/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6549
# Epoch 19/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6390
# Epoch 20/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6279
# Epoch 21/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6217
# Epoch 22/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5972
# Epoch 23/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5740
# Epoch 24/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5928
# Epoch 25/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5999
# Epoch 26/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5613
# Epoch 27/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5891
# Epoch 28/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5556
# Epoch 29/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5731
# Epoch 30/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5399
# Epoch 31/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5553
# Epoch 32/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5413
# Epoch 33/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5441
# Epoch 34/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5164
# Epoch 35/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5363
# Epoch 36/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5348
# Epoch 37/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5334
# Epoch 38/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5123
# Epoch 39/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4969
# Epoch 40/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5110
# Epoch 41/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5157
# Epoch 42/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5350
# Epoch 43/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5021
# Epoch 44/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4738
# Epoch 45/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4680
# Epoch 46/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4988
# Epoch 47/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4971
# Epoch 48/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4720
# Epoch 49/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4850
# Epoch 50/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4746
# Epoch 51/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4694
# Epoch 52/52
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4620
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# --- Optimized CNN Evaluation ---
# Train (CNN Optimized) MSE: 0.4238
# Train (CNN Optimized) RMSE: 0.6510
# Train (CNN Optimized) MAE: 0.5061
# Train (CNN Optimized) MAPE: 13.55%
# Train (CNN Optimized) R²: 0.8318
# Test (CNN Optimized) MSE: 0.5573
# Test (CNN Optimized) RMSE: 0.7465
# Test (CNN Optimized) MAE: 0.5733
# Test (CNN Optimized) MAPE: 15.29%
# Test (CNN Optimized) R²: 0.7689

# %%
## Data Set 1

# INSTALLING **PACKAGES**


# !pip install statsmodels

! pip install optuna

# !pip install tabulate

# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations

# Visualization
import matplotlib.pyplot as plt  # Plotting library
import seaborn as sns  # Statistical data visualization
from matplotlib.colors import ListedColormap  # Colormap utilities

# Model Helpers
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler  # Preprocessing tools
from sklearn import model_selection, metrics, preprocessing  # Model selection, evaluation, and preprocessing
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV  # Model selection and evaluation
from sklearn.tree import DecisionTreeClassifier  # Decision tree classifier


# Statistical analysis
from statsmodels.stats.outliers_influence import variance_inflation_factor  # Variance inflation factor
from scipy.stats import pointbiserialr, chi2_contingency, spearmanr, entropy  # Statistical functions
from statsmodels.graphics.gofplots import qqplot  # Q-Q plot
from collections import Counter  # Container datatypes

# Tabulate
from tabulate import tabulate  # Pretty-print tabular data

# Set visualization style
#sns.set()  # Set Seaborn default style
#plt.style.use('ggplot')  # Set ggplot style for matplotlib



# LOADING THE DATA SET
#https://drive.google.com/file/d/1Z_KsoIumw-fvivVombIoWuRo0LOe2nCb/view?usp=sharing
#https://drive.google.com/file/d/1aD1PXfwEEZ_F2lQgxuPfj-TVbxQ6NajK/view?usp=sharing
import gdown
import pandas as pd



# Read Xlsx file
import matplotlib.pyplot as plt
import pandas as pd
import plotly.graph_objects as go
import pandas as pd
import numpy as np  # Ensure numpy is imported
from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Read Xlsx file
import matplotlib.pyplot as plt
import pandas as pd
import plotly.graph_objects as go
import pandas as pd
import numpy as np  # Ensure numpy is imported
from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

import pandas as pd


from sklearn.model_selection import TimeSeriesSplit
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import (mean_absolute_error, mean_squared_error,
                            mean_absolute_percentage_error, r2_score)



from sklearn.model_selection import TimeSeriesSplit
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import (mean_absolute_error, mean_squared_error,
                            mean_absolute_percentage_error, r2_score)
import pandas as pd

# Load data from Google Drive
file_id = "1c5KmcFD1TOsqASqzy0KiYo-7IzgBFuhk"  # Using the new link you provided
download_url = f"https://drive.google.com/uc?id={file_id}"

# Read the data
df = pd.read_csv(download_url)

# Backup original DataFrame
df_backup = df.copy()

# Create datetime index
df['Date'] = pd.to_datetime({
    'year': df['YEAR'],
    'month': df['MO'],
    'day': df['DY']
})
df = df.set_index('Date')

# Drop unnecessary columns
df = df.drop(columns=["YEAR", "MO", "DY"])

# Display the DataFrame
print(df.head())



df.columns

df.columns
df
## Data Sets

# 1


df
###########################################################################################
# Define the list of variables to select

X = df.drop(columns=['WS10M'])
# Select only those columns from X
 # Features (lagged variables)
y = df['WS10M']  # Target variable (wind speed)

# Define the split index
split_index = int(len(X) * 0.8)  # 80% for training, 20% for testing

# Training set
X_train = X[:split_index]
y_train = y[:split_index]

# Testing set
X_test = X[split_index:]
y_test = y[split_index:]

numerical_cols=df.columns
numerical_cols

print("X_train:")
print(X_train.head())
print("y_train:")
print(y_train.head())
print("X_test:")
print(X_test.head())
print("y_test:")
print(y_test.head())

# Print the shapes of the datasets
print("\nShapes:")
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (2.3.1)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.16.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.4.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (0.9.0)
#             WS10M_lag1     RH  MIN_TEMP   PREC    WD_sin  SURF_PRESSURE_DIFF  \
# Date
# 2013-01-03        4.25  86.26     23.42  13.42  0.439939                0.03
# 2013-01-04        4.75  86.31     22.93   8.79  0.424199               -0.03
# 2013-01-05        5.74  86.88     22.17   2.60  0.563526               -0.15
# 2013-01-06        5.79  88.09     23.47   1.65  0.460200               -0.03
# 2013-01-07        4.52  93.04     24.04  27.41  0.368125               -0.01
#
#             AVG_TEMP    WD_cos  RH_lag1  MONOSOON_SEASON_Southwest_Monsoon  \
# Date
# 2013-01-03      26.4  0.898028    86.19                                  0
# 2013-01-04      25.1  0.905569    86.26                                  0
# 2013-01-05      26.9  0.826098    86.31                                  0
# 2013-01-06      27.3  0.887815    86.88                                  0
# 2013-01-07      25.9  0.929776    88.09                                  0
#
#             MAX_TEMP  SL_PRESSURE_lag1  CLOUD_COVER  WS10M
# Date
# 2013-01-03     28.38            1010.4          8.0   4.75
# 2013-01-04     27.58            1011.0          8.0   5.74
# 2013-01-05     26.16            1010.1          8.0   5.79
# 2013-01-06     27.75            1007.5          7.0   4.52
# 2013-01-07     26.70            1008.2          8.0   4.66
# X_train:
#             WS10M_lag1     RH  MIN_TEMP   PREC    WD_sin  SURF_PRESSURE_DIFF  \
# Date
# 2013-01-03        4.25  86.26     23.42  13.42  0.439939                0.03
# 2013-01-04        4.75  86.31     22.93   8.79  0.424199               -0.03
# 2013-01-05        5.74  86.88     22.17   2.60  0.563526               -0.15
# 2013-01-06        5.79  88.09     23.47   1.65  0.460200               -0.03
# 2013-01-07        4.52  93.04     24.04  27.41  0.368125               -0.01
#
#             AVG_TEMP    WD_cos  RH_lag1  MONOSOON_SEASON_Southwest_Monsoon  \
# Date
# 2013-01-03      26.4  0.898028    86.19                                  0
# 2013-01-04      25.1  0.905569    86.26                                  0
# 2013-01-05      26.9  0.826098    86.31                                  0
# 2013-01-06      27.3  0.887815    86.88                                  0
# 2013-01-07      25.9  0.929776    88.09                                  0
#
#             MAX_TEMP  SL_PRESSURE_lag1  CLOUD_COVER
# Date
# 2013-01-03     28.38            1010.4          8.0
# 2013-01-04     27.58            1011.0          8.0
# 2013-01-05     26.16            1010.1          8.0
# 2013-01-06     27.75            1007.5          7.0
# 2013-01-07     26.70            1008.2          8.0
# y_train:
# Date
# 2013-01-03    4.75
# 2013-01-04    5.74
# 2013-01-05    5.79
# 2013-01-06    4.52
# 2013-01-07    4.66
# Name: WS10M, dtype: float64
# X_test:
#             WS10M_lag1     RH  MIN_TEMP   PREC    WD_sin  SURF_PRESSURE_DIFF  \
# Date
# 2021-10-20        3.92  84.94     25.38  14.81 -0.914254                0.07
# 2021-10-21        2.82  86.10     25.29  33.26 -0.930418                0.01
# 2021-10-22        2.79  85.41     24.59   9.53 -0.810042                0.07
# 2021-10-23        2.72  85.24     24.52   9.21 -0.570714                0.10
# 2021-10-24        4.30  85.16     24.15  10.47 -0.979223               -0.03
#
#             AVG_TEMP    WD_cos  RH_lag1  MONOSOON_SEASON_Southwest_Monsoon  \
# Date
# 2021-10-20      27.9 -0.405142    83.84                                  0
# 2021-10-21      26.7 -0.366501    84.94                                  0
# 2021-10-22      28.1 -0.586372    86.10                                  0
# 2021-10-23      28.0 -0.821149    85.41                                  0
# 2021-10-24      26.6 -0.202787    85.24                                  0
#
#             MAX_TEMP  SL_PRESSURE_lag1  CLOUD_COVER
# Date
# 2021-10-20     28.73            1010.8          7.0
# 2021-10-21     28.72            1011.5          7.0
# 2021-10-22     28.80            1011.6          6.0
# 2021-10-23     28.17            1012.0          4.0
# 2021-10-24     27.91            1012.9          7.0
# y_test:
# Date
# 2021-10-20    2.82
# 2021-10-21    2.79
# 2021-10-22    2.72
# 2021-10-23    4.30
# 2021-10-24    3.74
# Name: WS10M, dtype: float64
#
# Shapes:
# X_train shape: (3212, 13)
# y_train shape: (3212,)
# X_test shape: (803, 13)
# y_test shape: (803,)

# %%
# Evaluation Function
def evaluate_metrics(y_true, y_pred, label=""):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    r2 = r2_score(y_true, y_pred)

    print(f"{label} MSE: {mse:.4f}")
    print(f"{label} RMSE: {rmse:.4f}")
    print(f"{label} MAE: {mae:.4f}")
    print(f"{label} MAPE: {mape:.2f}%")
    print(f"{label} R²: {r2:.4f}")
    return mse, rmse, mae, mape, r2

# %%
# Evaluation Function
def evaluate(y_true, y_pred, label=""):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    r2 = r2_score(y_true, y_pred)

    print(f"{label} MSE: {mse:.4f}")
    print(f"{label} RMSE: {rmse:.4f}")
    print(f"{label} MAE: {mae:.4f}")
    print(f"{label} MAPE: {mape:.2f}%")
    print(f"{label} R²: {r2:.4f}")
    return mse, rmse, mae, mape, r2

# %% [markdown]
# # CNN

# %% [markdown]
# ## Original

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import tensorflow as tf

# Set seed for reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# Assuming you have these from before:
# X_train_sub, X_test_sub (with selected top features)
# y_train, y_test (target variables)
# ===== CRITICAL ADDITION: STANDARD SCALING =====
# ... [imports and seed setting] ...

# Standard Scaling
scaler = StandardScaler()
X_train_sub = scaler.fit_transform(X_train)  # Now a NumPy array
X_test_sub = scaler.transform(X_test)        # Now a NumPy array

# Reshape for Conv1D
X_train_cnn = np.expand_dims(X_train_sub, axis=1)  # Shape: [samples, 1, features]
X_test_cnn = np.expand_dims(X_test_sub, axis=1)     # Shape: [samples, 1, features]

# Convert targets to arrays
y_train_cnn = y_train.values
y_test_cnn = y_test.values



# Build CNN model
model = Sequential()
# Conv1D expects input shape = (timesteps, features)
model.add(Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=(X_train_cnn.shape[1], X_train_cnn.shape[2])))
model.add(Flatten())  # Flatten before Dense layers
model.add(Dense(50, activation='relu'))
model.add(Dense(1))  # Output layer for regression

model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# Train the model
history = model.fit(
    X_train_cnn, y_train_cnn,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)

# Predict
y_train_pred_cnn = model.predict(X_train_cnn).flatten()
y_test_pred_cnn = model.predict(X_test_cnn).flatten()

# Evaluation function
def evaluate(y_true, y_pred, label="Model"):
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"{label}: MSE = {mse:.4f}, MAE = {mae:.4f}, R² = {r2:.4f}")

print("\n--- CNN Evaluation ---")
evaluate(y_train_cnn, y_train_pred_cnn, label="Train (CNN)")
evaluate(y_test_cnn, y_test_pred_cnn, label="Test (CNN)")

# Comparison dataframe
comparison_df = pd.DataFrame({
    'Actual': y_test_cnn,
    'Predicted': y_test_pred_cnn
})

print(comparison_df.head(20))

# Plot results
plt.figure(figsize=(10, 6))
plt.plot(y_test_cnn, label='Actual', marker='o')
plt.plot(y_test_pred_cnn, label='Predicted', marker='x')
plt.title('Actual vs Predicted Values (Test Set) - CNN')
plt.xlabel('Sample Index')
plt.ylabel('Target Value')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.4961 - val_loss: 1.2192
# Epoch 2/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8784 - val_loss: 0.8173
# Epoch 3/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6081 - val_loss: 0.6877
# Epoch 4/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5233 - val_loss: 0.6359
# Epoch 5/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4847 - val_loss: 0.6063
# Epoch 6/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4606 - val_loss: 0.5856
# Epoch 7/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4436 - val_loss: 0.5685
# Epoch 8/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4308 - val_loss: 0.5555
# Epoch 9/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4211 - val_loss: 0.5461
# Epoch 10/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4131 - val_loss: 0.5380
# Epoch 11/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4066 - val_loss: 0.5311
# Epoch 12/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4010 - val_loss: 0.5259
# Epoch 13/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3963 - val_loss: 0.5211
# Epoch 14/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3924 - val_loss: 0.5179
# Epoch 15/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3885 - val_loss: 0.5144
# Epoch 16/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3851 - val_loss: 0.5113
# Epoch 17/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3818 - val_loss: 0.5106
# Epoch 18/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3784 - val_loss: 0.5092
# Epoch 19/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3755 - val_loss: 0.5076
# Epoch 20/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3730 - val_loss: 0.5053
# Epoch 21/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3699 - val_loss: 0.5048
# Epoch 22/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3671 - val_loss: 0.5036
# Epoch 23/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3643 - val_loss: 0.5024
# Epoch 24/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3616 - val_loss: 0.5021
# Epoch 25/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3586 - val_loss: 0.5019
# Epoch 26/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3562 - val_loss: 0.5013
# Epoch 27/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.3536 - val_loss: 0.5012
# Epoch 28/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.3513 - val_loss: 0.5004
# Epoch 29/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3486 - val_loss: 0.5003
# Epoch 30/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3466 - val_loss: 0.5013
# Epoch 31/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3441 - val_loss: 0.5010
# Epoch 32/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.3418 - val_loss: 0.5016
# Epoch 33/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3391 - val_loss: 0.5011
# Epoch 34/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3367 - val_loss: 0.5014
# Epoch 35/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3348 - val_loss: 0.5013
# Epoch 36/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3324 - val_loss: 0.5019
# Epoch 37/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3300 - val_loss: 0.5018
# Epoch 38/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3280 - val_loss: 0.5018
# Epoch 39/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3263 - val_loss: 0.5028
# Epoch 40/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3238 - val_loss: 0.5046
# Epoch 41/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3223 - val_loss: 0.5063
# Epoch 42/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3200 - val_loss: 0.5058
# Epoch 43/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3182 - val_loss: 0.5075
# Epoch 44/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3161 - val_loss: 0.5083
# Epoch 45/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3140 - val_loss: 0.5101
# Epoch 46/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3120 - val_loss: 0.5099
# Epoch 47/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3104 - val_loss: 0.5111
# Epoch 48/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3080 - val_loss: 0.5133
# Epoch 49/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3064 - val_loss: 0.5123
# Epoch 50/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3045 - val_loss: 0.5142
# Epoch 51/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3026 - val_loss: 0.5152
# Epoch 52/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3008 - val_loss: 0.5174
# Epoch 53/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2986 - val_loss: 0.5182
# Epoch 54/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2963 - val_loss: 0.5186
# Epoch 55/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2957 - val_loss: 0.5192
# Epoch 56/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2930 - val_loss: 0.5225
# Epoch 57/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2917 - val_loss: 0.5233
# Epoch 58/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2900 - val_loss: 0.5268
# Epoch 59/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2875 - val_loss: 0.5278
# Epoch 60/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2854 - val_loss: 0.5273
# Epoch 61/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2836 - val_loss: 0.5296
# Epoch 62/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2814 - val_loss: 0.5321
# Epoch 63/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2804 - val_loss: 0.5333
# Epoch 64/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2782 - val_loss: 0.5349
# Epoch 65/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2761 - val_loss: 0.5355
# Epoch 66/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2745 - val_loss: 0.5379
# Epoch 67/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2727 - val_loss: 0.5380
# Epoch 68/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2703 - val_loss: 0.5405
# Epoch 69/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2681 - val_loss: 0.5425
# Epoch 70/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2661 - val_loss: 0.5448
# Epoch 71/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2641 - val_loss: 0.5473
# Epoch 72/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2625 - val_loss: 0.5475
# Epoch 73/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2608 - val_loss: 0.5512
# Epoch 74/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2594 - val_loss: 0.5534
# Epoch 75/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2570 - val_loss: 0.5558
# Epoch 76/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2548 - val_loss: 0.5579
# Epoch 77/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2539 - val_loss: 0.5618
# Epoch 78/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2514 - val_loss: 0.5634
# Epoch 79/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2501 - val_loss: 0.5653
# Epoch 80/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2479 - val_loss: 0.5709
# Epoch 81/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2466 - val_loss: 0.5704
# Epoch 82/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.2451 - val_loss: 0.5749
# Epoch 83/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2430 - val_loss: 0.5795
# Epoch 84/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2418 - val_loss: 0.5783
# Epoch 85/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2395 - val_loss: 0.5831
# Epoch 86/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2383 - val_loss: 0.5832
# Epoch 87/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2364 - val_loss: 0.5843
# Epoch 88/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2350 - val_loss: 0.5880
# Epoch 89/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2337 - val_loss: 0.5854
# Epoch 90/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2314 - val_loss: 0.5882
# Epoch 91/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2299 - val_loss: 0.5899
# Epoch 92/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2288 - val_loss: 0.5925
# Epoch 93/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2277 - val_loss: 0.5945
# Epoch 94/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2265 - val_loss: 0.5965
# Epoch 95/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2249 - val_loss: 0.5965
# Epoch 96/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2237 - val_loss: 0.5997
# Epoch 97/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2226 - val_loss: 0.6020
# Epoch 98/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2216 - val_loss: 0.6041
# Epoch 99/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2205 - val_loss: 0.6048
# Epoch 100/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2187 - val_loss: 0.6070
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# --- CNN Evaluation ---
# Train (CNN): MSE = 0.2903, MAE = 0.4078, R² = 0.8848
# Test (CNN): MSE = 0.6747, MAE = 0.6246, R² = 0.7202
#     Actual  Predicted
# 0     2.82   3.226261
# 1     2.79   2.536458
# 2     2.72   2.637442
# 3     4.30   2.834326
# 4     3.74   3.895532
# 5     2.69   2.793499
# 6     2.37   3.164072
# 7     2.30   2.689931
# 8     3.50   3.634524
# 9     4.15   2.413576
# 10    1.97   3.199770
# 11    5.60   5.256509
# 12    6.11   4.748370
# 13    2.57   4.360141
# 14    3.27   2.703235
# 15    3.36   2.748010
# 16    3.55   3.508190
# 17    4.03   3.355617
# 18    5.18   2.990923
# 19    5.81   4.401392

# %%
# !pip install scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from scikeras) (3.8.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from scikeras) (1.6.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (3.14.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.16.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (25.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras>=3.2.0->scikeras) (4.14.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0

# %%
import sklearn, scikeras, tensorflow
print("scikit-learn:", sklearn.__version__)
print("scikeras:", scikeras.__version__)
print("tensorflow:", tensorflow.__version__)
# Out:
# scikit-learn: 1.6.1
# scikeras: 0.13.0
# tensorflow: 2.18.0

# %%
# !pip install --force-reinstall --no-cache-dir numpy scikit-learn
# Out:
# Collecting numpy
#   Downloading numpy-2.3.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 3.8 MB/s eta 0:00:00
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 158.9 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading numpy-2.3.1-cp311-cp311-manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 92.5 MB/s eta 0:00:00
# Downloading scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 53.7 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 207.4 MB/s eta 0:00:00
# Downloading scipy-1.16.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 42.0 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, numpy, joblib, scipy, scikit-learn
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.6.0
#     Uninstalling threadpoolctl-3.6.0:
#       Successfully uninstalled threadpoolctl-3.6.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.5.1
#     Uninstalling joblib-1.5.1:
#       Successfully uninstalled joblib-1.5.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.0
#     Uninstalling scipy-1.16.0:
#       Successfully uninstalled scipy-1.16.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.1 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.1 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.3.1 which is incompatible.
# cupy-cuda12x 13.3.0 requires numpy<2.3,>=1.22, but you have numpy 2.3.1 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.1 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.1 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.1 which is incompatible.
# Successfully installed joblib-1.5.1 numpy-2.3.1 scikit-learn-1.7.1 scipy-1.16.0 threadpoolctl-3.6.0

# %% [markdown]
# ## Grid Search

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
#from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from scikeras.wrappers import KerasRegressor

from tensorflow.keras.optimizers import Adam
# Fix random seed for reproducibility
RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# Standard Scaling
scaler = StandardScaler()
X_train_sub = scaler.fit_transform(X_train)  # Now a NumPy array
X_test_sub = scaler.transform(X_test)        # Now a NumPy array

# Reshape for Conv1D
X_train_cnn = np.expand_dims(X_train_sub, axis=1)  # Shape: [samples, 1, features]
X_test_cnn = np.expand_dims(X_test_sub, axis=1)     # Shape: [samples, 1, features]

# Convert targets to arrays
y_train_cnn = y_train.values
y_test_cnn = y_test.values


# Evaluation function (same as yours)
def evaluate_metrics(y_true, y_pred, label=""):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    r2 = r2_score(y_true, y_pred)

    print(f"{label} MSE: {mse:.4f}")
    print(f"{label} RMSE: {rmse:.4f}")
    print(f"{label} MAE: {mae:.4f}")
    print(f"{label} MAPE: {mape:.2f}%")
    print(f"{label} R²: {r2:.4f}")
    return mse, rmse, mae, mape, r2

# Build CNN model builder function for KerasRegressor
def build_cnn_model(filters=64, kernel_size=1, dropout_rate=0.2, learning_rate=0.001):
    model = Sequential()
    model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='relu', input_shape=(1, X_train.shape[1])))
    model.add(Flatten())
    model.add(Dropout(dropout_rate))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(loss='mse', optimizer=optimizer)
    return model

# Wrap Keras model for sklearn compatibility
cnn_regressor = KerasRegressor(model=build_cnn_model, verbose=0)

# Parameter grid with correct scikeras prefixes
param_grid = {
    'model__filters': [32, 64, 128],
    'model__dropout_rate': [0.1, 0.2, 0.3],
    'model__learning_rate': [1e-2, 1e-3, 1e-4],
    'batch_size': [16, 32],
    'epochs': [50, 100]
}

# TimeSeriesSplit for cross-validation
tscv = TimeSeriesSplit(n_splits=5)

# Setup GridSearchCV
grid_search = GridSearchCV(
    estimator=cnn_regressor,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',
    cv=tscv,
    verbose=2,
    n_jobs=1  # Parallelism with TF often causes issues
)

# Fit grid search (this will take time)
grid_search.fit(X_train_cnn, y_train)

print("\nBest Parameters found:")
print(grid_search.best_params_)

# Best model from grid search
best_cnn = grid_search.best_estimator_

# Predictions
y_train_pred = best_cnn.predict(X_train_cnn)
y_test_pred = best_cnn.predict(X_test_cnn)

print("\n--- Optimized CNN Evaluation ---")
evaluate_metrics(y_train, y_train_pred, label="Train (CNN Optimized)")
evaluate_metrics(y_test, y_test_pred, label="Test (CNN Optimized)")

# Plot results
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='Actual', color='black', linewidth=2)
plt.plot(y_test_pred, label='Predicted (CNN Optimized)', color='blue', linestyle='--', linewidth=2)
plt.title('Actual vs Predicted Values on Test Set (Optimized CNN)')
plt.xlabel('Observation Index')
plt.ylabel('Target Value')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  24.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  17.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  17.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  22.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  29.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  12.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  14.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  17.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  25.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  30.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=   9.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  15.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  18.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  26.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  31.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=   9.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  13.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  18.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  26.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  29.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=   9.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  15.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  19.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  26.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  31.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  10.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  15.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  19.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  31.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  30.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  11.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  13.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  17.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  29.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  32.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  10.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  15.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  23.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  28.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  33.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=   9.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  15.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  18.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  28.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  30.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=   8.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  12.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  18.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  26.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  30.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  11.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  14.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  19.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  26.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  30.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=   9.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  15.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  18.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  24.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  30.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=   9.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  14.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  17.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  25.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  30.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=   9.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  14.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  17.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  30.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  34.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=   8.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  16.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  17.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  27.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  31.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=   8.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  16.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  17.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  27.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  30.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=   8.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  15.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  18.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  27.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  31.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=   8.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  14.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  16.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  26.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  33.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=   9.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  15.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  17.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  24.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  30.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=   9.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  15.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  17.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  25.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  30.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=   7.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  14.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  17.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  23.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  30.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=   9.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  14.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  17.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  25.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  32.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=   9.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  14.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  21.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  27.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  32.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=   8.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  16.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  19.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  27.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  31.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=   9.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  15.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  17.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  27.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  29.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=   9.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  15.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  18.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  27.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  31.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=   9.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  14.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  18.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  26.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  30.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  15.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  27.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  32.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  47.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  56.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  19.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  29.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  33.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  55.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  59.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  16.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  28.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  33.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  48.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  59.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  18.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  28.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  33.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  48.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  58.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  17.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  25.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  32.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  48.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time= 1.0min
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  16.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  29.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  32.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  54.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time= 1.0min
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  16.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  29.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  35.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  56.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time= 1.0min
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  16.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  29.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  39.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  55.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time= 1.1min
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  16.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  31.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  34.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  53.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time= 1.0min
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  16.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  27.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  32.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  51.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  58.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  17.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  26.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  32.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  47.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  59.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  15.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  27.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  33.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  45.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  58.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  17.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  25.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  31.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  45.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  57.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  16.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  28.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  33.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  54.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time= 1.0min
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  15.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  28.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  33.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  52.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time= 1.1min
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  16.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  30.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  33.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  55.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time= 1.1min
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  16.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  28.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  35.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  52.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time= 1.0min
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  15.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  27.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  34.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  50.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time= 1.0min
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  16.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  28.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  32.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  42.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time= 1.0min
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  16.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  26.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  32.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  45.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  59.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  16.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  27.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  33.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  45.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  56.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  16.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  25.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  31.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  50.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  57.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  15.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  25.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  33.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  46.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  55.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  15.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  27.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  33.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  54.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time= 1.1min
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  16.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  29.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  33.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  55.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time= 1.1min
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  16.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  29.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  33.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  48.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time= 1.0min
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  16.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  27.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  32.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  49.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time= 1.0min
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=   7.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=   9.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  12.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  14.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  15.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=   7.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=   9.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  10.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  13.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  18.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=   7.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=   8.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  12.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  14.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  17.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=   7.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=   9.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  12.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  15.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  17.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=   6.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=   9.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  14.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  15.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  17.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=   7.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=   9.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  12.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  14.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  17.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=   8.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=   9.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  14.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  20.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  17.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=   8.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  10.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  14.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  16.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  18.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=   6.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=   9.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  13.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  17.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  16.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=   7.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=   8.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  12.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  16.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  16.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=   7.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=   8.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  13.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  13.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  16.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=   6.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=   9.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  12.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  15.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  16.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=   7.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=   9.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  13.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  15.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  17.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=   6.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=   9.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  12.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  14.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  17.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=   7.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=   9.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  13.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  17.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  16.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=   7.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=   8.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  13.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  16.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  16.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=   8.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=   8.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  14.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  16.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  16.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=   7.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=   8.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  14.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  14.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  16.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=   7.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  16.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  13.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  15.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  18.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=   7.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=   9.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  13.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  16.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  16.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=   8.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=   8.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  13.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  15.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  16.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=   8.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=   9.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  14.7s
# ...
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  31.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  12.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  17.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  27.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  29.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  32.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  13.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  17.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  27.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  29.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  39.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  14.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  19.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  26.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  32.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  31.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  13.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  17.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  26.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  32.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  34.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  14.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  18.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  26.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  29.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  33.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  13.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  18.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  26.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  31.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  33.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  13.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  16.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  26.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  28.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  30.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  12.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  16.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  25.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  28.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  32.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  13.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  17.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  24.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  26.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  32.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  13.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  16.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  24.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  29.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  31.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  13.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  18.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  26.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  31.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  32.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  13.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  16.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  26.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  29.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  33.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  13.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  15.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  25.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  29.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  32.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  13.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  17.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  24.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  27.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  33.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  13.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  16.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  25.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  30.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  31.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  13.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  18.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  22.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  26.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  30.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  12.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  15.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  21.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  27.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  32.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  13.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  15.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  22.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  38.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  32.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  14.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  18.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  26.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  29.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  32.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  13.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  17.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  25.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  31.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  33.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  14.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  16.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  25.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  31.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  31.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  13.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  17.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  26.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  32.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  33.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  13.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  17.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  25.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  30.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  33.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  14.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  17.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  26.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  29.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  32.0s
#
# Best Parameters found:
# {'batch_size': 16, 'epochs': 50, 'model__dropout_rate': 0.3, 'model__filters': 128, 'model__learning_rate': 0.001}
#
# --- Optimized CNN Evaluation ---
# Train (CNN Optimized) MSE: 0.3447
# Train (CNN Optimized) RMSE: 0.5871
# Train (CNN Optimized) MAE: 0.4624
# Train (CNN Optimized) MAPE: 12.65%
# Train (CNN Optimized) R²: 0.8632
# Test (CNN Optimized) MSE: 0.5586
# Test (CNN Optimized) RMSE: 0.7474
# Test (CNN Optimized) MAE: 0.5735
# Test (CNN Optimized) MAPE: 15.41%
# Test (CNN Optimized) R²: 0.7683

# %% [markdown]
# ## Random Search

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense, Dropout
from scikeras.wrappers import KerasRegressor
from tensorflow.keras.optimizers import Adam
from scipy.stats import randint, uniform
import tensorflow as tf
import random

# Fix random seed for reproducibility
RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# Standard Scaling
scaler = StandardScaler()
X_train_sub = scaler.fit_transform(X_train)  # Now a NumPy array
X_test_sub = scaler.transform(X_test)        # Now a NumPy array

# Reshape for Conv1D
X_train_cnn = np.expand_dims(X_train_sub, axis=1)  # Shape: [samples, 1, features]
X_test_cnn = np.expand_dims(X_test_sub, axis=1)     # Shape: [samples, 1, features]

# Convert targets to arrays
y_train_cnn = y_train.values
y_test_cnn = y_test.values


# Define CNN model builder function for KerasRegressor
def create_cnn_model(filters=64, dropout_rate=0.2, learning_rate=0.001):
    model = Sequential()
    model.add(Conv1D(filters=filters, kernel_size=1, activation='relu', input_shape=(1, X_train.shape[1])))
    model.add(Flatten())
    model.add(Dropout(dropout_rate))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))  # Regression output
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(loss='mse', optimizer=optimizer)
    return model

# Wrap model for sklearn compatibility
from scikeras.wrappers import KerasRegressor

cnn_regressor = KerasRegressor(
    model=create_cnn_model,
    verbose=0,
    filters=64,
    dropout_rate=0.2,
    learning_rate=0.001
)

# Define hyperparameter distribution for RandomizedSearchCV
param_dist = {
    'filters': randint(20, 151),
    'dropout_rate': uniform(0.1, 0.3),
    'learning_rate': uniform(1e-4, 9e-3),
    'batch_size': randint(16, 65),
    'epochs': randint(50, 151)
}

# Setup RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=cnn_regressor,
    param_distributions=param_dist,
    n_iter=10,
    cv=3,
    random_state=RANDOM_SEED,
    verbose=2,
    n_jobs=1
)

# Fit RandomizedSearchCV
random_search.fit(X_train_cnn, y_train)

# Best parameters
print("Best Hyperparameters:", random_search.best_params_)

# Predict on train and test sets using best estimator
y_train_pred_cnn = random_search.predict(X_train_cnn)
y_test_pred_cnn = random_search.predict(X_test_cnn)

# Evaluation function
def evaluate(y_true, y_pred, label="Model"):
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"{label}: MSE = {mse:.4f}, MAE = {mae:.4f}, R² = {r2:.4f}")

print("\n--- CNN Evaluation ---")
evaluate(y_train, y_train_pred_cnn, label="Train (CNN)")
evaluate(y_test, y_test_pred_cnn, label="Test (CNN)")

# Create a DataFrame to compare actual and predicted values on test set
comparison_df = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_test_pred_cnn
})

print(comparison_df.head(20))

# Plot actual vs predicted for test set
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='Actual', marker='o')
plt.plot(y_test_pred_cnn, label='Predicted', marker='x')
plt.title('Actual vs Predicted Values (Test Set) - CNN')
plt.xlabel('Sample Index')
plt.ylabel('Target Value')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] END batch_size=54, dropout_rate=0.33896289605806984, epochs=64, filters=126, learning_rate=0.007117219002454924; total time=  34.8s
# [CV] END batch_size=54, dropout_rate=0.33896289605806984, epochs=64, filters=126, learning_rate=0.007117219002454924; total time=  17.8s
# [CV] END batch_size=54, dropout_rate=0.33896289605806984, epochs=64, filters=126, learning_rate=0.007117219002454924; total time=  17.7s
# [CV] END batch_size=36, dropout_rate=0.14680559213273095, epochs=132, filters=94, learning_rate=0.004233240027692805; total time=  39.2s
# [CV] END batch_size=36, dropout_rate=0.14680559213273095, epochs=132, filters=94, learning_rate=0.004233240027692805; total time=  42.5s
# [CV] END batch_size=36, dropout_rate=0.14680559213273095, epochs=132, filters=94, learning_rate=0.004233240027692805; total time=  38.2s
# [CV] END batch_size=51, dropout_rate=0.14286004537658223, epochs=52, filters=72, learning_rate=0.008829188669457947; total time=  13.3s
# [CV] END batch_size=51, dropout_rate=0.14286004537658223, epochs=52, filters=72, learning_rate=0.008829188669457947; total time=  14.8s
# [CV] END batch_size=51, dropout_rate=0.14286004537658223, epochs=52, filters=72, learning_rate=0.008829188669457947; total time=  13.5s
# [CV] END batch_size=59, dropout_rate=0.381565812704725, epochs=51, filters=40, learning_rate=0.005657333586649448; total time=  12.1s
# [CV] END batch_size=59, dropout_rate=0.381565812704725, epochs=51, filters=40, learning_rate=0.005657333586649448; total time=  12.4s
# [CV] END batch_size=59, dropout_rate=0.381565812704725, epochs=51, filters=40, learning_rate=0.005657333586649448; total time=  10.6s
# [CV] END batch_size=37, dropout_rate=0.10211989156591522, epochs=138, filters=68, learning_rate=0.004822971942325502; total time=  39.2s
# [CV] END batch_size=37, dropout_rate=0.10211989156591522, epochs=138, filters=68, learning_rate=0.004822971942325502; total time=  39.5s
# [CV] END batch_size=37, dropout_rate=0.10211989156591522, epochs=138, filters=68, learning_rate=0.004822971942325502; total time=  38.9s
# [CV] END batch_size=57, dropout_rate=0.11399969896408463, epochs=109, filters=34, learning_rate=0.0042046298579533235; total time=  21.3s
# [CV] END batch_size=57, dropout_rate=0.11399969896408463, epochs=109, filters=34, learning_rate=0.0042046298579533235; total time=  19.2s
# [CV] END batch_size=57, dropout_rate=0.11399969896408463, epochs=109, filters=34, learning_rate=0.0042046298579533235; total time=  22.6s
# [CV] END batch_size=62, dropout_rate=0.28551580279992617, epochs=104, filters=83, learning_rate=0.00430086603923182; total time=  19.7s
# [CV] END batch_size=62, dropout_rate=0.28551580279992617, epochs=104, filters=83, learning_rate=0.00430086603923182; total time=  19.4s
# [CV] END batch_size=62, dropout_rate=0.28551580279992617, epochs=104, filters=83, learning_rate=0.00430086603923182; total time=  19.7s
# [CV] END batch_size=52, dropout_rate=0.28226345557043153, epochs=70, filters=92, learning_rate=0.0006854643368675156; total time=  17.3s
# [CV] END batch_size=52, dropout_rate=0.28226345557043153, epochs=70, filters=92, learning_rate=0.0006854643368675156; total time=  18.1s
# [CV] END batch_size=52, dropout_rate=0.28226345557043153, epochs=70, filters=92, learning_rate=0.0006854643368675156; total time=  17.3s
# [CV] END batch_size=19, dropout_rate=0.3826605267054558, epochs=63, filters=28, learning_rate=0.00024369626998192772; total time=  28.1s
# [CV] END batch_size=19, dropout_rate=0.3826605267054558, epochs=63, filters=28, learning_rate=0.00024369626998192772; total time=  28.4s
# [CV] END batch_size=19, dropout_rate=0.3826605267054558, epochs=63, filters=28, learning_rate=0.00024369626998192772; total time=  33.4s
# [CV] END batch_size=17, dropout_rate=0.30526990795364706, epochs=109, filters=27, learning_rate=0.0004094966900369655; total time=  55.2s
# [CV] END batch_size=17, dropout_rate=0.30526990795364706, epochs=109, filters=27, learning_rate=0.0004094966900369655; total time=  56.8s
# [CV] END batch_size=17, dropout_rate=0.30526990795364706, epochs=109, filters=27, learning_rate=0.0004094966900369655; total time=  54.7s
# Best Hyperparameters: {'batch_size': 52, 'dropout_rate': np.float64(0.28226345557043153), 'epochs': 70, 'filters': 92, 'learning_rate': np.float64(0.0006854643368675156)}
#
# --- CNN Evaluation ---
# Train (CNN): MSE = 0.4291, MAE = 0.5112, R² = 0.8297
# Test (CNN): MSE = 0.5983, MAE = 0.5961, R² = 0.7519
#             Actual  Predicted
# Date
# 2021-10-20    2.82   3.547674
# 2021-10-21    2.79   2.824164
# 2021-10-22    2.72   2.681695
# 2021-10-23    4.30   2.672757
# 2021-10-24    3.74   3.328439
# 2021-10-25    2.69   3.625652
# 2021-10-26    2.37   2.767856
# 2021-10-27    2.30   2.341542
# 2021-10-28    3.50   3.119117
# 2021-10-29    4.15   3.700948
# 2021-10-30    1.97   3.324657
# 2021-10-31    5.60   3.919562
# 2021-11-01    6.11   4.571581
# 2021-11-02    2.57   3.993189
# 2021-11-03    3.27   3.222394
# 2021-11-04    3.36   3.259936
# 2021-11-05    3.55   3.461934
# 2021-11-06    4.03   3.763375
# 2021-11-07    5.18   4.021231
# 2021-11-08    5.81   4.271734

# %% [markdown]
# ## optuna

# %%
import optuna
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# ===== CRITICAL ADDITION: STANDARD SCALING =====
# Standard Scaling
scaler = StandardScaler()
X_train_sub = scaler.fit_transform(X_train)  # Now a NumPy array
X_test_sub = scaler.transform(X_test)        # Now a NumPy array

# Reshape for Conv1D
X_train_cnn = np.expand_dims(X_train_sub, axis=1)  # Shape: [samples, 1, features]
X_test_cnn = np.expand_dims(X_test_sub, axis=1)     # Shape: [samples, 1, features]

# Convert targets to arrays
y_train_cnn = y_train.values
y_test_cnn = y_test.values



# Fix random seed
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)



# Evaluation function (same as you used)
def evaluate_metrics(y_true, y_pred, label=""):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    r2 = r2_score(y_true, y_pred)

    print(f"{label} MSE: {mse:.4f}")
    print(f"{label} RMSE: {rmse:.4f}")
    print(f"{label} MAE: {mae:.4f}")
    print(f"{label} MAPE: {mape:.2f}%")
    print(f"{label} R²: {r2:.4f}")
    return mse, rmse, mae, mape, r2

# Build CNN model function for Optuna
def create_cnn_model(trial):
    filters = trial.suggest_int('filters', 20, 150)
    dropout_rate = trial.suggest_float('dropout_rate', 0.1, 0.5)
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-4, 1e-2)

    model = Sequential()
    model.add(Conv1D(filters=filters, kernel_size=1, activation='relu', input_shape=(1, X_train.shape[1])))
    model.add(Flatten())
    model.add(Dropout(dropout_rate))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))  # Regression output
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(loss='mse', optimizer=optimizer)
    return model

# Optuna objective for CNN
def cnn_objective(trial):
    batch_size = trial.suggest_categorical('batch_size', [16, 32, 64])
    epochs = trial.suggest_int('epochs', 50, 150)

    model = create_cnn_model(trial)

    tscv = TimeSeriesSplit(n_splits=5)
    rmse_scores = []

    for train_idx, val_idx in tscv.split(X_train_cnn):
        X_t, X_v = X_train_cnn[train_idx], X_train_cnn[val_idx]
        y_t, y_v = y_train.iloc[train_idx], y_train.iloc[val_idx]

        history = model.fit(
            X_t, y_t,
            validation_data=(X_v, y_v),
            epochs=epochs,
            batch_size=batch_size,
            verbose=0,
            shuffle=False
        )
        preds = model.predict(X_v).flatten()
        rmse = mean_squared_error(y_v, preds)
        rmse_scores.append(rmse)

    return np.mean(rmse_scores)

# Create and run Optuna study
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED))
study.optimize(cnn_objective, n_trials=30, timeout=600)

print("\nBest Trial:")
print(study.best_trial)
print("\nBest Parameters:")
print(study.best_params)

# Refit final model on full train data with best params
best_params = study.best_params

final_model = Sequential()
final_model.add(Conv1D(filters=best_params['filters'], kernel_size=1, activation='relu', input_shape=(1, X_train.shape[1])))
final_model.add(Flatten())
final_model.add(Dropout(best_params['dropout_rate']))
final_model.add(Dense(50, activation='relu'))
final_model.add(Dense(1))
optimizer = Adam(learning_rate=best_params['learning_rate'])
final_model.compile(loss='mse', optimizer=optimizer)

final_model.fit(
    X_train_cnn, y_train,
    epochs=best_params['epochs'],
    batch_size=best_params['batch_size'],
    verbose=1,
    shuffle=False
)

# Predict
y_train_pred = final_model.predict(X_train_cnn).flatten()
y_test_pred = final_model.predict(X_test_cnn).flatten()

print("\n--- Optimized CNN Evaluation ---")
evaluate_metrics(y_train, y_train_pred, label="Train (CNN Optimized)")
evaluate_metrics(y_test, y_test_pred, label="Test (CNN Optimized)")

# Plot results
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='Actual', color='black', linewidth=2)
plt.plot(y_test_pred, label='Predicted (CNN Optimized)', color='blue', linestyle='--', linewidth=2)
plt.title('Actual vs Predicted Values on Test Set (Optimized CNN)')
plt.xlabel('Observation Index')
plt.ylabel('Target Value')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# [I 2025-07-23 10:07:40,349] A new study created in memory with name: no-name-19c73246-420d-4ee1-8912-32ba04e08bdb
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [I 2025-07-23 10:11:23,008] Trial 0 finished with value: 0.6172743398470552 and parameters: {'batch_size': 32, 'epochs': 110, 'filters': 40, 'dropout_rate': 0.16239780813448107, 'learning_rate': 0.00013066739238053285}. Best is trial 0 with value: 0.6172743398470552.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [I 2025-07-23 10:13:56,722] Trial 1 finished with value: 0.5402687587674798 and parameters: {'batch_size': 16, 'epochs': 52, 'filters': 147, 'dropout_rate': 0.4329770563201687, 'learning_rate': 0.00026587543983272726}. Best is trial 1 with value: 0.5402687587674798.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [I 2025-07-23 10:16:12,382] Trial 2 finished with value: 0.5646037350819466 and parameters: {'batch_size': 64, 'epochs': 103, 'filters': 76, 'dropout_rate': 0.21649165607921678, 'learning_rate': 0.0016738085788752138}. Best is trial 1 with value: 0.5402687587674798.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [I 2025-07-23 10:18:18,802] Trial 3 finished with value: 0.5303143631965809 and parameters: {'batch_size': 64, 'epochs': 96, 'filters': 122, 'dropout_rate': 0.1798695128633439, 'learning_rate': 0.0010677482709481358}. Best is trial 3 with value: 0.5303143631965809.
# Best Trial:
# FrozenTrial(number=3, state=1, values=[0.5303143631965809], datetime_start=datetime.datetime(2025, 7, 23, 10, 16, 12, 383754), datetime_complete=datetime.datetime(2025, 7, 23, 10, 18, 18, 802546), params={'batch_size': 64, 'epochs': 96, 'filters': 122, 'dropout_rate': 0.1798695128633439, 'learning_rate': 0.0010677482709481358}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'batch_size': CategoricalDistribution(choices=(16, 32, 64)), 'epochs': IntDistribution(high=150, log=False, low=50, step=1), 'filters': IntDistribution(high=150, log=False, low=20, step=1), 'dropout_rate': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'learning_rate': FloatDistribution(high=0.01, log=True, low=0.0001, step=None)}, trial_id=3, value=None)
#
# Best Parameters:
# {'batch_size': 64, 'epochs': 96, 'filters': 122, 'dropout_rate': 0.1798695128633439, 'learning_rate': 0.0010677482709481358}
# Epoch 1/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 12.0723
# Epoch 2/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2873
# Epoch 3/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9497
# Epoch 4/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8274
# Epoch 5/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7771
# Epoch 6/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6941
# Epoch 7/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6726
# Epoch 8/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6422
# Epoch 9/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5936
# Epoch 10/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5873
# Epoch 11/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5665
# Epoch 12/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5541
# Epoch 13/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5730
# Epoch 14/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5574
# Epoch 15/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5409
# Epoch 16/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5506
# Epoch 17/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5178
# Epoch 18/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5258
# Epoch 19/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5215
# Epoch 20/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5118
# Epoch 21/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5247
# Epoch 22/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4884
# Epoch 23/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4962
# Epoch 24/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4850
# Epoch 25/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4839
# Epoch 26/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5001
# Epoch 27/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4863
# Epoch 28/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4871
# Epoch 29/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4835
# Epoch 30/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4604
# Epoch 31/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4737
# Epoch 32/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4499
# Epoch 33/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4860
# Epoch 34/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4690
# Epoch 35/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4576
# Epoch 36/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4529
# Epoch 37/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4744
# Epoch 38/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4573
# Epoch 39/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4462
# Epoch 40/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4540
# Epoch 41/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4388
# Epoch 42/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4394
# Epoch 43/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4529
# Epoch 44/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4268
# Epoch 45/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4497
# Epoch 46/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4624
# Epoch 47/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4337
# Epoch 48/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4365
# Epoch 49/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4308
# Epoch 50/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4276
# Epoch 51/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4207
# Epoch 52/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4354
# Epoch 53/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4223
# Epoch 54/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4263
# Epoch 55/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4166
# Epoch 56/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4073
# Epoch 57/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4231
# Epoch 58/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4255
# Epoch 59/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4247
# Epoch 60/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4050
# Epoch 61/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3948
# Epoch 62/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3999
# Epoch 63/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4231
# Epoch 64/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4089
# Epoch 65/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4040
# Epoch 66/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4074
# Epoch 67/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3926
# Epoch 68/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3833
# Epoch 69/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3847
# Epoch 70/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3908
# Epoch 71/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3952
# Epoch 72/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3917
# Epoch 73/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3751
# Epoch 74/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3973
# Epoch 75/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3916
# Epoch 76/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3840
# Epoch 77/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3738
# Epoch 78/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3797
# Epoch 79/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3746
# Epoch 80/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3695
# Epoch 81/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3819
# Epoch 82/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3810
# Epoch 83/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3702
# Epoch 84/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3810
# Epoch 85/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3681
# Epoch 86/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3690
# Epoch 87/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3754
# Epoch 88/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3639
# Epoch 89/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3731
# Epoch 90/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3709
# Epoch 91/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3642
# Epoch 92/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3729
# Epoch 93/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3609
# Epoch 94/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3590
# Epoch 95/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3772
# Epoch 96/96
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3700
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# --- Optimized CNN Evaluation ---
# Train (CNN Optimized) MSE: 0.3249
# Train (CNN Optimized) RMSE: 0.5700
# Train (CNN Optimized) MAE: 0.4425
# Train (CNN Optimized) MAPE: 11.85%
# Train (CNN Optimized) R²: 0.8710
# Test (CNN Optimized) MSE: 0.5463
# Test (CNN Optimized) RMSE: 0.7391
# Test (CNN Optimized) MAE: 0.5708
# Test (CNN Optimized) MAPE: 15.00%
# Test (CNN Optimized) R²: 0.7735

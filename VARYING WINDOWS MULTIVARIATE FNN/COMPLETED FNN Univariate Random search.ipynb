# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import TimeSeriesSplit
import random

# Set seeds
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Load data
sheet_id = "1j_Euo80PrGckVDVr2hTG9zZebxJD0TSC"
sheet_name = "Sheet1"
csv_url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
df = pd.read_csv(csv_url)
df = df.set_index('Date').drop(columns=["YEAR", "MO", "DY"])
df = df[["WS10M"]].astype(float)

# Function to create lagged features
def create_lagged_features(df, lags):
    lagged_df = df.copy()
    for col in df.columns:
        for lag in range(1, lags + 1):
            lagged_df[f"{col}_lag_{lag}"] = df[col].shift(lag)
    return lagged_df

# Function to generate random hyperparameters
def generate_random_params(X_shape):
    params = {
        'input_units': random.choice(range(16, 129, 16)),
        'activation': random.choice(["relu", "tanh", "sigmoid"]),
        'num_layers': random.randint(1, 3),
        'optimizer': random.choice(["Adam", "SGD", "RMSprop"]),
        'batch_size': random.choice([16, 32, 48, 64]),
        'epochs': random.choice([10, 20, 30, 40, 50])
    }

    for i in range(params['num_layers']):
        params[f'n_units_{i}'] = random.choice(range(16, 129, 16))
        params[f'dropout_rate_{i}'] = random.uniform(0.0, 0.5)

    return params

# Function to create model from parameters
def create_model_from_params(params, X_shape):
    model = Sequential()
    model.add(Dense(params['input_units'],
                    input_dim=X_shape[1],
                    activation=params['activation']))

    for i in range(params['num_layers']):
        model.add(Dense(params[f'n_units_{i}'],
                        activation=params['activation']))
        model.add(Dropout(params[f'dropout_rate_{i}']))

    model.add(Dense(1))

    optimizer = {
        "Adam": Adam(),
        "SGD": SGD(),
        "RMSprop": RMSprop()
    }[params['optimizer']]

    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# Run the modeling pipeline for each lag
def run_model_for_lag(lag, n_trials=15):
    print(f"\n========= Running Model for Lag {lag} =========")
    df_lagged = create_lagged_features(df, lag).dropna()

    train_size = int(len(df_lagged) * 0.8)
    train, test = df_lagged.iloc[:train_size], df_lagged.iloc[train_size:]

    X_train, y_train = train.drop(columns=["WS10M"]), train["WS10M"]
    X_test, y_test = test.drop(columns=["WS10M"]), test["WS10M"]

    scaler_X, scaler_y = MinMaxScaler(), MinMaxScaler()
    X_train_scaled = scaler_X.fit_transform(X_train)
    X_test_scaled = scaler_X.transform(X_test)
    y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1)).ravel()
    y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1))

    X_train_df = pd.DataFrame(X_train_scaled, columns=X_train.columns)
    y_train_series = pd.Series(y_train_scaled)

    best_val_loss = float('inf')
    best_params = None

    # Random search
    for trial in range(n_trials):
        print(f"Trial {trial+1}/{n_trials}")
        params = generate_random_params(X_train_df.shape)

        tscv = TimeSeriesSplit(n_splits=3)
        val_losses = []

        for train_idx, val_idx in tscv.split(X_train_df):
            X_t, X_v = X_train_df.iloc[train_idx], X_train_df.iloc[val_idx]
            y_t, y_v = y_train_series.iloc[train_idx], y_train_series.iloc[val_idx]

            model = create_model_from_params(params, X_t.shape)

            history = model.fit(
                X_t, y_t,
                epochs=params['epochs'],
                batch_size=params['batch_size'],
                validation_data=(X_v, y_v),
                verbose=0
            )

            val_loss = history.history['val_loss'][-1]
            val_losses.append(val_loss)

        mean_val_loss = np.mean(val_losses)
        print(f"Params: {params}\nMean Val Loss: {mean_val_loss:.4f}")

        if mean_val_loss < best_val_loss:
            best_val_loss = mean_val_loss
            best_params = params
            print("New best params found!")

    print("\nBest Params:", best_params)
    print("Best Validation Loss:", best_val_loss)

    # Final model training with best params
    model = create_model_from_params(best_params, X_train_df.shape)
    history = model.fit(
        X_train_df, y_train_series,
        epochs=best_params['epochs'],
        batch_size=best_params['batch_size'],
        validation_split=0.1,
        verbose=0
    )

    # Predict
    X_test_df = pd.DataFrame(X_test_scaled, columns=X_test.columns)
    predictions_scaled = model.predict(X_test_df)
    predictions = scaler_y.inverse_transform(predictions_scaled)
    y_test_inv = scaler_y.inverse_transform(y_test_scaled)

    # Metrics
    mse = mean_squared_error(y_test_inv, predictions)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test_inv, predictions)
    mape = np.mean(np.abs((y_test_inv - predictions) / y_test_inv)) * 100
    r2 = r2_score(y_test_inv, predictions)

    print(f"\nFinal Metrics:")
    print(f"MSE: {mse:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}, MAPE: {mape:.2f}%, R²: {r2:.4f}")

    # Plot
    plt.figure(figsize=(10, 5))
    plt.plot(y_test_inv, label="Actual", linestyle="--")
    plt.plot(predictions, label="Predicted")
    plt.title(f"Lag {lag} - Actual vs Predicted")
    plt.xlabel("Samples")
    plt.ylabel("WS10M")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return best_params

# Run the loop for lag = 1 to 14
for lag in range(1, 15):
    run_model_for_lag(lag)
# Out:
# ========= Running Model for Lag 1 =========
# Trial 1/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 32, 'activation': 'relu', 'num_layers': 3, 'optimizer': 'SGD', 'batch_size': 32, 'epochs': 20, 'n_units_0': 48, 'dropout_rate_0': 0.3682356070820062, 'n_units_1': 32, 'dropout_rate_1': 0.29524625622451983, 'n_units_2': 16, 'dropout_rate_2': 0.014898609719035172}
# Mean Val Loss: 0.0141
# New best params found!
# Trial 2/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 96, 'activation': 'tanh', 'num_layers': 1, 'optimizer': 'Adam', 'batch_size': 48, 'epochs': 10, 'n_units_0': 32, 'dropout_rate_0': 0.1899636503186687}
# Mean Val Loss: 0.0087
# New best params found!
# Trial 3/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 112, 'activation': 'relu', 'num_layers': 3, 'optimizer': 'SGD', 'batch_size': 48, 'epochs': 50, 'n_units_0': 64, 'dropout_rate_0': 0.35228591810746174, 'n_units_1': 16, 'dropout_rate_1': 0.3306316592838551, 'n_units_2': 80, 'dropout_rate_2': 0.49261076033037887}
# Mean Val Loss: 0.0144
# Trial 4/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 64, 'activation': 'relu', 'num_layers': 2, 'optimizer': 'SGD', 'batch_size': 48, 'epochs': 50, 'n_units_0': 64, 'dropout_rate_0': 0.3423071254949373, 'n_units_1': 16, 'dropout_rate_1': 0.11452403598205219}
# Mean Val Loss: 0.0108
# Trial 5/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 128, 'activation': 'relu', 'num_layers': 2, 'optimizer': 'Adam', 'batch_size': 32, 'epochs': 50, 'n_units_0': 80, 'dropout_rate_0': 0.37350690582612894, 'n_units_1': 112, 'dropout_rate_1': 0.4489114418012385}
# Mean Val Loss: 0.0093
# Trial 6/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 32, 'activation': 'tanh', 'num_layers': 2, 'optimizer': 'RMSprop', 'batch_size': 64, 'epochs': 50, 'n_units_0': 80, 'dropout_rate_0': 0.4855391888068091, 'n_units_1': 16, 'dropout_rate_1': 0.34014170512825925}
# Mean Val Loss: 0.0091
# Trial 7/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 80, 'activation': 'sigmoid', 'num_layers': 1, 'optimizer': 'RMSprop', 'batch_size': 16, 'epochs': 30, 'n_units_0': 64, 'dropout_rate_0': 0.0764196342748174}
# Mean Val Loss: 0.0094
# Trial 8/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 32, 'activation': 'tanh', 'num_layers': 2, 'optimizer': 'Adam', 'batch_size': 16, 'epochs': 20, 'n_units_0': 32, 'dropout_rate_0': 0.04282672603393939, 'n_units_1': 128, 'dropout_rate_1': 0.40801162671004426}
# Mean Val Loss: 0.0093
# Trial 9/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 64, 'activation': 'sigmoid', 'num_layers': 2, 'optimizer': 'SGD', 'batch_size': 48, 'epochs': 40, 'n_units_0': 128, 'dropout_rate_0': 0.06050209793413286, 'n_units_1': 64, 'dropout_rate_1': 0.03201294816317246}
# Mean Val Loss: 0.0339
# Trial 10/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 64, 'activation': 'tanh', 'num_layers': 3, 'optimizer': 'SGD', 'batch_size': 32, 'epochs': 50, 'n_units_0': 48, 'dropout_rate_0': 0.3616762829404854, 'n_units_1': 128, 'dropout_rate_1': 0.12149862119786226, 'n_units_2': 128, 'dropout_rate_2': 0.4037484988833217}
# Mean Val Loss: 0.0088
# Trial 11/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 64, 'activation': 'relu', 'num_layers': 3, 'optimizer': 'SGD', 'batch_size': 32, 'epochs': 40, 'n_units_0': 48, 'dropout_rate_0': 0.13927257233347023, 'n_units_1': 64, 'dropout_rate_1': 0.43724297703528997, 'n_units_2': 32, 'dropout_rate_2': 0.22156537252672848}
# Mean Val Loss: 0.0118
# Trial 12/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 112, 'activation': 'relu', 'num_layers': 2, 'optimizer': 'SGD', 'batch_size': 64, 'epochs': 30, 'n_units_0': 112, 'dropout_rate_0': 0.34829575180008127, 'n_units_1': 128, 'dropout_rate_1': 0.07739841263703207}
# Mean Val Loss: 0.0122
# Trial 13/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 16, 'activation': 'sigmoid', 'num_layers': 1, 'optimizer': 'Adam', 'batch_size': 16, 'epochs': 50, 'n_units_0': 32, 'dropout_rate_0': 0.3376062768020451}
# Mean Val Loss: 0.0161
# Trial 14/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 96, 'activation': 'tanh', 'num_layers': 1, 'optimizer': 'RMSprop', 'batch_size': 48, 'epochs': 20, 'n_units_0': 80, 'dropout_rate_0': 0.19789292339562725}
# Mean Val Loss: 0.0094
# Trial 15/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 32, 'activation': 'relu', 'num_layers': 3, 'optimizer': 'Adam', 'batch_size': 48, 'epochs': 20, 'n_units_0': 96, 'dropout_rate_0': 0.44043208684321977, 'n_units_1': 64, 'dropout_rate_1': 0.18476354436944198, 'n_units_2': 48, 'dropout_rate_2': 0.21909228650385493}
# Mean Val Loss: 0.0120
#
# Best Params: {'input_units': 96, 'activation': 'tanh', 'num_layers': 1, 'optimizer': 'Adam', 'batch_size': 48, 'epochs': 10, 'n_units_0': 32, 'dropout_rate_0': 0.1899636503186687}
# Best Validation Loss: 0.008745571598410606
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Final Metrics:
# MSE: 0.7684, RMSE: 0.8766, MAE: 0.6722, MAPE: 19.13%, R²: 0.6810
# ========= Running Model for Lag 2 =========
# Trial 1/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 96, 'activation': 'relu', 'num_layers': 3, 'optimizer': 'RMSprop', 'batch_size': 48, 'epochs': 50, 'n_units_0': 128, 'dropout_rate_0': 0.12556062603494705, 'n_units_1': 16, 'dropout_rate_1': 0.04614923385636671, 'n_units_2': 112, 'dropout_rate_2': 0.41467404468610963}
# Mean Val Loss: 0.0091
# New best params found!
# Trial 2/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 96, 'activation': 'sigmoid', 'num_layers': 3, 'optimizer': 'Adam', 'batch_size': 64, 'epochs': 20, 'n_units_0': 16, 'dropout_rate_0': 0.15412917496506684, 'n_units_1': 16, 'dropout_rate_1': 0.4494623182632373, 'n_units_2': 64, 'dropout_rate_2': 0.34103334415528824}
# Mean Val Loss: 0.0343
# Trial 3/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 96, 'activation': 'tanh', 'num_layers': 3, 'optimizer': 'RMSprop', 'batch_size': 32, 'epochs': 30, 'n_units_0': 48, 'dropout_rate_0': 0.39368725456773557, 'n_units_1': 32, 'dropout_rate_1': 0.19127086129846715, 'n_units_2': 16, 'dropout_rate_2': 0.4292966256688908}
# Mean Val Loss: 0.0097
# Trial 4/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 112, 'activation': 'sigmoid', 'num_layers': 3, 'optimizer': 'SGD', 'batch_size': 16, 'epochs': 10, 'n_units_0': 80, 'dropout_rate_0': 0.08928390808623182, 'n_units_1': 80, 'dropout_rate_1': 0.01912859867663136, 'n_units_2': 112, 'dropout_rate_2': 0.17284355583990013}
# Mean Val Loss: 0.0368
# Trial 5/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 64, 'activation': 'tanh', 'num_layers': 2, 'optimizer': 'Adam', 'batch_size': 48, 'epochs': 50, 'n_units_0': 96, 'dropout_rate_0': 0.33169373813277214, 'n_units_1': 32, 'dropout_rate_1': 0.3598771315069751}
# Mean Val Loss: 0.0088
# New best params found!
# Trial 6/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 48, 'activation': 'sigmoid', 'num_layers': 3, 'optimizer': 'SGD', 'batch_size': 64, 'epochs': 50, 'n_units_0': 16, 'dropout_rate_0': 0.1519374746341769, 'n_units_1': 64, 'dropout_rate_1': 0.2149440749949173, 'n_units_2': 96, 'dropout_rate_2': 0.2324940951235071}
# Mean Val Loss: 0.0338
# Trial 7/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 64, 'activation': 'relu', 'num_layers': 1, 'optimizer': 'Adam', 'batch_size': 16, 'epochs': 20, 'n_units_0': 128, 'dropout_rate_0': 0.30563698653034005}
# Mean Val Loss: 0.0088
# Trial 8/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 112, 'activation': 'relu', 'num_layers': 1, 'optimizer': 'RMSprop', 'batch_size': 16, 'epochs': 10, 'n_units_0': 112, 'dropout_rate_0': 0.10942056840615971}
# Mean Val Loss: 0.0101
# Trial 9/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 128, 'activation': 'sigmoid', 'num_layers': 3, 'optimizer': 'RMSprop', 'batch_size': 48, 'epochs': 40, 'n_units_0': 112, 'dropout_rate_0': 0.4152845848607075, 'n_units_1': 128, 'dropout_rate_1': 0.4486040516166311, 'n_units_2': 128, 'dropout_rate_2': 0.22503487862345406}
# Mean Val Loss: 0.0343
# Trial 10/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 48, 'activation': 'relu', 'num_layers': 2, 'optimizer': 'RMSprop', 'batch_size': 32, 'epochs': 20, 'n_units_0': 32, 'dropout_rate_0': 0.20743394794910908, 'n_units_1': 96, 'dropout_rate_1': 0.2713055702519577}
# Mean Val Loss: 0.0098
# Trial 11/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 96, 'activation': 'tanh', 'num_layers': 2, 'optimizer': 'SGD', 'batch_size': 32, 'epochs': 40, 'n_units_0': 64, 'dropout_rate_0': 0.1364676558816283, 'n_units_1': 128, 'dropout_rate_1': 0.01451240997335762}
# Mean Val Loss: 0.0088
# Trial 12/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 16, 'activation': 'relu', 'num_layers': 3, 'optimizer': 'SGD', 'batch_size': 32, 'epochs': 40, 'n_units_0': 48, 'dropout_rate_0': 0.025142316744313775, 'n_units_1': 112, 'dropout_rate_1': 0.16367633347086713, 'n_units_2': 128, 'dropout_rate_2': 0.16342290244065427}
# Mean Val Loss: 0.0098
# Trial 13/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 64, 'activation': 'relu', 'num_layers': 1, 'optimizer': 'RMSprop', 'batch_size': 32, 'epochs': 20, 'n_units_0': 48, 'dropout_rate_0': 0.23678053047306402}
# Mean Val Loss: 0.0095
# Trial 14/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 32, 'activation': 'relu', 'num_layers': 2, 'optimizer': 'Adam', 'batch_size': 16, 'epochs': 30, 'n_units_0': 112, 'dropout_rate_0': 0.19832722075831366, 'n_units_1': 64, 'dropout_rate_1': 0.03799823892152998}
# Mean Val Loss: 0.0089
# Trial 15/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 112, 'activation': 'sigmoid', 'num_layers': 2, 'optimizer': 'Adam', 'batch_size': 48, 'epochs': 10, 'n_units_0': 112, 'dropout_rate_0': 0.41116545904502905, 'n_units_1': 32, 'dropout_rate_1': 0.21676170066292422}
# Mean Val Loss: 0.0343
#
# Best Params: {'input_units': 64, 'activation': 'tanh', 'num_layers': 2, 'optimizer': 'Adam', 'batch_size': 48, 'epochs': 50, 'n_units_0': 96, 'dropout_rate_0': 0.33169373813277214, 'n_units_1': 32, 'dropout_rate_1': 0.3598771315069751}
# Best Validation Loss: 0.008771707924703756
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Final Metrics:
# MSE: 0.7886, RMSE: 0.8880, MAE: 0.6810, MAPE: 18.61%, R²: 0.6730
# ========= Running Model for Lag 3 =========
# Trial 1/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 80, 'activation': 'tanh', 'num_layers': 1, 'optimizer': 'Adam', 'batch_size': 48, 'epochs': 40, 'n_units_0': 64, 'dropout_rate_0': 0.3752381409135031}
# Mean Val Loss: 0.0088
# New best params found!
# Trial 2/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 96, 'activation': 'tanh', 'num_layers': 2, 'optimizer': 'SGD', 'batch_size': 48, 'epochs': 50, 'n_units_0': 16, 'dropout_rate_0': 0.2583136258574671, 'n_units_1': 64, 'dropout_rate_1': 0.04280648097901063}
# Mean Val Loss: 0.0097
# Trial 3/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 64, 'activation': 'tanh', 'num_layers': 3, 'optimizer': 'RMSprop', 'batch_size': 48, 'epochs': 40, 'n_units_0': 96, 'dropout_rate_0': 0.21275190635260738, 'n_units_1': 96, 'dropout_rate_1': 0.17590526380708416, 'n_units_2': 128, 'dropout_rate_2': 0.13545821348809817}
# Mean Val Loss: 0.0102
# Trial 4/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 64, 'activation': 'tanh', 'num_layers': 1, 'optimizer': 'SGD', 'batch_size': 32, 'epochs': 30, 'n_units_0': 16, 'dropout_rate_0': 0.35400924285551566}
# Mean Val Loss: 0.0093
# Trial 5/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 32, 'activation': 'relu', 'num_layers': 3, 'optimizer': 'SGD', 'batch_size': 64, 'epochs': 40, 'n_units_0': 128, 'dropout_rate_0': 0.17035296628014618, 'n_units_1': 16, 'dropout_rate_1': 0.1262391952464863, 'n_units_2': 128, 'dropout_rate_2': 0.05704357036246227}
# Mean Val Loss: 0.0155
# Trial 6/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 112, 'activation': 'tanh', 'num_layers': 2, 'optimizer': 'SGD', 'batch_size': 64, 'epochs': 30, 'n_units_0': 16, 'dropout_rate_0': 0.30481545612256516, 'n_units_1': 32, 'dropout_rate_1': 0.473795100162689}
# Mean Val Loss: 0.0104
# Trial 7/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ...
# Mean Val Loss: 0.0097
# New best params found!
# Trial 4/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 80, 'activation': 'sigmoid', 'num_layers': 1, 'optimizer': 'SGD', 'batch_size': 64, 'epochs': 40, 'n_units_0': 112, 'dropout_rate_0': 0.41106118507952677}
# Mean Val Loss: 0.0339
# Trial 5/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 80, 'activation': 'sigmoid', 'num_layers': 1, 'optimizer': 'SGD', 'batch_size': 48, 'epochs': 10, 'n_units_0': 48, 'dropout_rate_0': 0.061617579466749506}
# Mean Val Loss: 0.0327
# Trial 6/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 96, 'activation': 'relu', 'num_layers': 2, 'optimizer': 'RMSprop', 'batch_size': 32, 'epochs': 20, 'n_units_0': 48, 'dropout_rate_0': 0.11039398467870398, 'n_units_1': 80, 'dropout_rate_1': 0.09716310767316272}
# Mean Val Loss: 0.0134
# Trial 7/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 64, 'activation': 'sigmoid', 'num_layers': 3, 'optimizer': 'SGD', 'batch_size': 48, 'epochs': 30, 'n_units_0': 48, 'dropout_rate_0': 0.33564778289002545, 'n_units_1': 64, 'dropout_rate_1': 0.05002252863771145, 'n_units_2': 32, 'dropout_rate_2': 0.4500592954214609}
# Mean Val Loss: 0.0336
# Trial 8/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 112, 'activation': 'tanh', 'num_layers': 2, 'optimizer': 'Adam', 'batch_size': 48, 'epochs': 40, 'n_units_0': 128, 'dropout_rate_0': 0.2226789867831081, 'n_units_1': 80, 'dropout_rate_1': 0.24348569121834568}
# Mean Val Loss: 0.0091
# New best params found!
# Trial 9/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 32, 'activation': 'relu', 'num_layers': 3, 'optimizer': 'RMSprop', 'batch_size': 16, 'epochs': 50, 'n_units_0': 112, 'dropout_rate_0': 0.38460012745125705, 'n_units_1': 64, 'dropout_rate_1': 0.4531517886990916, 'n_units_2': 80, 'dropout_rate_2': 0.27173466195905926}
# Mean Val Loss: 0.0125
# Trial 10/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 64, 'activation': 'sigmoid', 'num_layers': 3, 'optimizer': 'Adam', 'batch_size': 32, 'epochs': 40, 'n_units_0': 48, 'dropout_rate_0': 0.08957259195431039, 'n_units_1': 48, 'dropout_rate_1': 0.3679599044174122, 'n_units_2': 128, 'dropout_rate_2': 0.4695876291349364}
# Mean Val Loss: 0.0339
# Trial 11/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 96, 'activation': 'relu', 'num_layers': 3, 'optimizer': 'RMSprop', 'batch_size': 48, 'epochs': 30, 'n_units_0': 48, 'dropout_rate_0': 0.18832978477208057, 'n_units_1': 112, 'dropout_rate_1': 0.18264838899552382, 'n_units_2': 32, 'dropout_rate_2': 0.25833144877696934}
# Mean Val Loss: 0.0097
# Trial 12/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 80, 'activation': 'relu', 'num_layers': 1, 'optimizer': 'Adam', 'batch_size': 32, 'epochs': 30, 'n_units_0': 32, 'dropout_rate_0': 0.3305548214552787}
# Mean Val Loss: 0.0090
# New best params found!
# Trial 13/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 112, 'activation': 'relu', 'num_layers': 1, 'optimizer': 'Adam', 'batch_size': 32, 'epochs': 50, 'n_units_0': 48, 'dropout_rate_0': 0.06736202400006508}
# Mean Val Loss: 0.0097
# Trial 14/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 16, 'activation': 'sigmoid', 'num_layers': 3, 'optimizer': 'RMSprop', 'batch_size': 48, 'epochs': 10, 'n_units_0': 64, 'dropout_rate_0': 0.22460168080972837, 'n_units_1': 128, 'dropout_rate_1': 0.4336511994960472, 'n_units_2': 48, 'dropout_rate_2': 0.10968190740929384}
# Mean Val Loss: 0.0352
# Trial 15/15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Params: {'input_units': 48, 'activation': 'relu', 'num_layers': 1, 'optimizer': 'Adam', 'batch_size': 64, 'epochs': 20, 'n_units_0': 32, 'dropout_rate_0': 0.08871109215866468}
# Mean Val Loss: 0.0091
#
# Best Params: {'input_units': 80, 'activation': 'relu', 'num_layers': 1, 'optimizer': 'Adam', 'batch_size': 32, 'epochs': 30, 'n_units_0': 32, 'dropout_rate_0': 0.3305548214552787}
# Best Validation Loss: 0.009012097803254923
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Final Metrics:
# MSE: 0.7403, RMSE: 0.8604, MAE: 0.6684, MAPE: 19.04%, R²: 0.6930
